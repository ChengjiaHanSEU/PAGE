# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.activations import relu
from tensorflow.keras.layers import *
from tensorflow.keras import Model
from tensorflow.keras import layers as Layers
import numpy as np
import math
import sys
import os
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt
from plyfile import *
from mpl_toolkits.mplot3d import Axes3D
import open3d as o3d 
import numpy as np
import scipy.stats
import random
import pandas as pd
from sklearn.metrics import confusion_matrix
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
#点云文件导入
##############导入点云数据#################
pcd_AC13_1 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC13-1.ply")
pcd_AC13_2 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC13-2.ply")
pcd_AC16_3 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC16-3.ply")
pcd_AC16_4 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC16-4.ply")
pcd_UT5_1  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-1.ply")
pcd_UT5_2  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-2.ply")
pcd_UT5_3  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-3.ply")
pcd_UT5_4  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-4.ply")
pcd_SMA13_1= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/SMA13-1.ply")
pcd_SMA13_2= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/SMA13-2.ply")
pcd_OGFC10_1= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/OGFC10-1.ply")
#############点云标准化####################
def standard_pointcloud(point_cloud):
    Point_standard=[]
    Point=np.asarray(point_cloud.points)    
    x=np.array(Point[:,0])[...,np.newaxis]
    y=np.array(Point[:,1])[...,np.newaxis]
    z=np.array(Point[:,2])[...,np.newaxis]
    Point_standard=np.concatenate((x-np.min(x),y-np.min(y),z-np.min(z)),axis=-1)
    return Point_standard
    
AC13_1=standard_pointcloud(pcd_AC13_1)
AC13_2=standard_pointcloud(pcd_AC13_2)
AC16_3=standard_pointcloud(pcd_AC16_3)
AC16_4=standard_pointcloud(pcd_AC16_4)
UT5_1=standard_pointcloud(pcd_UT5_1)
UT5_2=standard_pointcloud(pcd_UT5_2)
UT5_3=standard_pointcloud(pcd_UT5_3)
UT5_4=standard_pointcloud(pcd_UT5_4)
SMA13_1= standard_pointcloud(pcd_SMA13_1)
SMA13_2= standard_pointcloud(pcd_SMA13_2)
OGFC10_1 =  standard_pointcloud(pcd_OGFC10_1)

point_cloud_array_group = []
point_cloud_array_group.append(AC13_1)
point_cloud_array_group.append(AC13_2)
point_cloud_array_group.append(AC16_3)
point_cloud_array_group.append(AC16_4)
point_cloud_array_group.append(UT5_1)
point_cloud_array_group.append(UT5_2)
point_cloud_array_group.append(UT5_3)
point_cloud_array_group.append(UT5_4)
point_cloud_array_group.append(SMA13_1)
point_cloud_array_group.append(SMA13_2)
point_cloud_array_group.append(OGFC10_1)
#############点云标准化####################
def standard_pointcloud(point_cloud):
    Point_standard=[]  
    x=np.array(point_cloud[:,0])[...,np.newaxis]
    y=np.array(point_cloud[:,1])[...,np.newaxis]
    z=np.array(point_cloud[:,2])[...,np.newaxis]
    Point_standard=np.concatenate((x-np.min(x),y-np.min(y),z-np.min(z)),axis=-1)
    return Point_standard
######################按照计算的H_final进行窗口滑动切分#########################
H_final=51
AC13=[0,6,4,3.5,5.5,7.5,10.5,16,23.5,18.5,5,0]#级配
AC16=[0,5.4,2.4,2.4,3.7,4.1,7.8,5.5,26.3,20.1,16.6,5.7]#级配 
SMA13=[0,10.7,2.1,1.4,1.1,1.2,2.9,9.4,30.3,31.5,8.2,1.2]#级配
UT5=[0,6.7,2,2.5,5,20,13.4,48.8,1.5,0.1,0,0]#级配
OGFC10=[0,4,1.5,2,2,2.5,4,44,35,5,0,0]#级配
def split_slide(point_cloud_array_origion,H_new=H_final, intervial =[5,5]):
    L=int(np.max(point_cloud_array_origion[:,0]))
    W=int(np.max(point_cloud_array_origion[:,1]))
    Point_cloud_small = []
    L_intervial = intervial[0]
    W_intervial = intervial[1]
    for i in range (0,L-H_new,L_intervial):
        for j in range (0,W-H_new,W_intervial):
            temp_point_cloud = point_cloud_array_origion[np.where((point_cloud_array_origion[:,1]>i)&
                                                                  (point_cloud_array_origion[:,1]<(H_new+i))&
                                                                  (point_cloud_array_origion[:,0]>j)&
                                                                  (point_cloud_array_origion[:,0]<(H_new+j)))]
            temp_point_cloud = standard_pointcloud(temp_point_cloud)
            Point_cloud_small.append(temp_point_cloud)
    return Point_cloud_small
########################点云转RCBD图像############
def PointCloud_to_RGBD(pointCloud_array):
    pcd=o3d.geometry.PointCloud()
    pcd.points=o3d.utility.Vector3dVector(pointCloud_array)
    vis = o3d.visualization.Visualizer()
    vis.create_window()
    vis.get_render_option().point_color_option = o3d.visualization.PointColorOption.Color
    vis.get_render_option().point_size = 3.0
    vis.add_geometry(pcd)
    Image=vis.capture_screen_float_buffer(do_render=True)
    vis.destroy_window()
    Image_array = np.array(Image)[150:900,580:1320]
    return Image_array
############开始制作数据###################
PointCloud_new =[]
#制作Ground truth
Y_Data=np.zeros((1,12))
for i in range(11):
    temp=split_slide(point_cloud_array_group[i])
    #print(len(temp))
    PointCloud_new=np.concatenate((PointCloud_new,temp),axis=0)
    if (i==0) or (i==1):
        temp2 = np.full((len(temp),12),AC13)
    elif (i==2) or (i==3):
        temp2 = np.full((len(temp),12),AC16)
    elif (i==4) or (i==5) or (i==6) or (i==7):
        temp2 = np.full((len(temp),12),UT5)
    elif (i==8) or (i==9):
        temp2 = np.full((len(temp),12),SMA13)
    elif (i==10):
        temp2 = np.full((len(temp),12),OGFC10) 
    #print(temp2.shape)
    Y_Data = np.concatenate((Y_Data,temp2),axis=0)
Y_Data = np.delete(Y_Data, 1, 0)#把第一行0删掉
print(Y_Data.shape)
Image_set=[]
for i in range(len(PointCloud_new )):
    temp = PointCloud_to_RGBD(PointCloud_new[i])
    Image_set.append(temp)
Image_set=np.array(Image_set)
print(Image_set.shape)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# (1579, 12)
# (1579, 750, 740, 3)

# %%
#### 数据集1397分，切分为1200训练 197测试#######################
arr = np.array(range(0, 1579, 1))
r = np.random.permutation(arr)
Train_X_Data = []
Train_Y_Data = []
for i in range(1379):
    Train_X_Data.append(Image_set[r[i]])
    Train_Y_Data.append(Y_Data[r[i]])

Test_X_Data = []
Test_Y_Data = []
for i in range(1379,1579):
    Test_X_Data.append(Image_set[r[i]])
    Test_Y_Data.append(Y_Data[r[i]])
    
Train_X_Data = np.array(Train_X_Data)
Train_Y_Data = np.array(Train_Y_Data)
Test_X_Data = np.array(Test_X_Data)
Test_Y_Data = np.array(Test_Y_Data)

print(Train_X_Data.shape)
print(Train_Y_Data.shape)
print(Test_X_Data.shape)
print(Test_Y_Data.shape)
# Out:
# (1379, 750, 740, 3)
# (1379, 12)
# (200, 750, 740, 3)
# (200, 12)

# %%
def convolutional(input_layer, filters_shape, downsample=False, activate=True, bn=True):
    if downsample:
        input_layer = tf.keras.layers.ZeroPadding2D(((1, 0), (1, 0)))(input_layer)
        padding = 'valid'
        strides = 2
    else:
        strides = 1
        padding = 'same'

    conv = tf.keras.layers.Conv2D(filters=filters_shape[-1], kernel_size = filters_shape[0], strides=strides, padding=padding,
                                  use_bias=not bn, kernel_regularizer=tf.keras.regularizers.l2(0.0005),
                                  kernel_initializer=tf.random_normal_initializer(stddev=0.01),
                                  bias_initializer=tf.constant_initializer(0.))(input_layer)

    if bn: conv = tf.keras.layers.BatchNormalization()(conv)
    if activate == True: conv = tf.nn.leaky_relu(conv, alpha=0.1)

    return conv

def residual_block(input_layer, input_channel, filter_num1, filter_num2):
    short_cut = input_layer
    conv = convolutional(input_layer, filters_shape=(1, 1, input_channel, filter_num1))
    conv = convolutional(conv       , filters_shape=(3, 3, filter_num1,   filter_num2))

    residual_output = short_cut + conv
    residual_output = tf.keras.layers.BatchNormalization()(residual_output)
    return residual_output

def upsample(input_layer):
    return tf.image.resize(input_layer, (input_layer.shape[1] * 2, input_layer.shape[2] * 2), method='nearest')

def Darknet53(input_data,num_classes):

    input_data = convolutional(input_data, (3, 3,  3,  32))
    input_data = convolutional(input_data, (3, 3, 32,  64), downsample=True)

    for i in range(1):
        input_data = residual_block(input_data,  64,  32, 64)

    input_data = convolutional(input_data, (3, 3,  64, 128), downsample=True)

    for i in range(2):
        input_data = residual_block(input_data, 128,  64, 128)

    input_data = convolutional(input_data, (3, 3, 128, 256), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 256, 128, 256)

    input_data = convolutional(input_data, (3, 3, 256, 512), downsample=True)

    for i in range(8):
        input_data = residual_block(input_data, 512, 256, 512)

    input_data = convolutional(input_data, (3, 3, 512, 1024), downsample=True)

    for i in range(4):
        input_data = residual_block(input_data, 1024, 512, 1024)
    
    input_data = tf.keras.layers.GlobalAveragePooling2D()(input_data)
    input_data = tf.keras.layers.Dense(256, activation='relu')(input_data)
    input_data = tf.keras.layers.Dense(256, activation='relu')(input_data)
    input_data = tf.keras.layers.Dense(num_classes, activation='relu')(input_data)

    return input_data

# %%
input_tensor = tf.keras.layers.Input([750, 740, 3])
conv_tensors = Darknet53(input_tensor,num_classes=12)
model = tf.keras.Model(input_tensor, conv_tensors)
model.summary()
Batch_size=8
lr=1e-3
model.compile(optimizer=keras.optimizers.Adam(lr), loss=tf.keras.losses.MAE)
Callback = tf.keras.callbacks.ModelCheckpoint("Darknet53.h5", 
                                           monitor='val_loss', 
                                           save_best_only=True, 
                                           save_weights_only=True)
Model_history=model.fit(x=Train_X_Data,y=Train_Y_Data,batch_size=Batch_size,epochs =200, validation_split=0.2, callbacks=Callback)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 750, 740, 3) 0
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 750, 740, 32) 864         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_225 (BatchN (None, 750, 740, 32) 128         conv2d_156[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_156 (TFOpLambd (None, 750, 740, 32) 0           batch_normalization_225[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 751, 741, 32) 0           tf.nn.leaky_relu_156[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 375, 370, 64) 18432       zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_226 (BatchN (None, 375, 370, 64) 256         conv2d_157[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_157 (TFOpLambd (None, 375, 370, 64) 0           batch_normalization_226[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 375, 370, 32) 2048        tf.nn.leaky_relu_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_227 (BatchN (None, 375, 370, 32) 128         conv2d_158[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_158 (TFOpLambd (None, 375, 370, 32) 0           batch_normalization_227[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 375, 370, 64) 18432       tf.nn.leaky_relu_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_228 (BatchN (None, 375, 370, 64) 256         conv2d_159[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_159 (TFOpLambd (None, 375, 370, 64) 0           batch_normalization_228[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_69 (TFOpLa (None, 375, 370, 64) 0           tf.nn.leaky_relu_157[0][0]
#                                                                  tf.nn.leaky_relu_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_229 (BatchN (None, 375, 370, 64) 256         tf.__operators__.add_69[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 376, 371, 64) 0           batch_normalization_229[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 187, 185, 128 73728       zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_230 (BatchN (None, 187, 185, 128 512         conv2d_160[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_160 (TFOpLambd (None, 187, 185, 128 0           batch_normalization_230[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 187, 185, 64) 8192        tf.nn.leaky_relu_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_231 (BatchN (None, 187, 185, 64) 256         conv2d_161[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_161 (TFOpLambd (None, 187, 185, 64) 0           batch_normalization_231[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 187, 185, 128 73728       tf.nn.leaky_relu_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_232 (BatchN (None, 187, 185, 128 512         conv2d_162[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_162 (TFOpLambd (None, 187, 185, 128 0           batch_normalization_232[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_70 (TFOpLa (None, 187, 185, 128 0           tf.nn.leaky_relu_160[0][0]
#                                                                  tf.nn.leaky_relu_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_233 (BatchN (None, 187, 185, 128 512         tf.__operators__.add_70[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 187, 185, 64) 8192        batch_normalization_233[0][0]
# __________________________________________________________________________________________________
# batch_normalization_234 (BatchN (None, 187, 185, 64) 256         conv2d_163[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_163 (TFOpLambd (None, 187, 185, 64) 0           batch_normalization_234[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 187, 185, 128 73728       tf.nn.leaky_relu_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_235 (BatchN (None, 187, 185, 128 512         conv2d_164[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_164 (TFOpLambd (None, 187, 185, 128 0           batch_normalization_235[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_71 (TFOpLa (None, 187, 185, 128 0           batch_normalization_233[0][0]
#                                                                  tf.nn.leaky_relu_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_236 (BatchN (None, 187, 185, 128 512         tf.__operators__.add_71[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 188, 186, 128 0           batch_normalization_236[0][0]
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 93, 92, 256)  294912      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_237 (BatchN (None, 93, 92, 256)  1024        conv2d_165[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_165 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_237[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 93, 92, 128)  32768       tf.nn.leaky_relu_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_238 (BatchN (None, 93, 92, 128)  512         conv2d_166[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_166 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_238[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_239 (BatchN (None, 93, 92, 256)  1024        conv2d_167[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_167 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_239[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_72 (TFOpLa (None, 93, 92, 256)  0           tf.nn.leaky_relu_165[0][0]
#                                                                  tf.nn.leaky_relu_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_240 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_72[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_240[0][0]
# __________________________________________________________________________________________________
# batch_normalization_241 (BatchN (None, 93, 92, 128)  512         conv2d_168[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_168 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_241[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_168[0][0]
# __________________________________________________________________________________________________
# batch_normalization_242 (BatchN (None, 93, 92, 256)  1024        conv2d_169[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_169 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_242[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_73 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_240[0][0]
#                                                                  tf.nn.leaky_relu_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_243 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_73[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_243[0][0]
# __________________________________________________________________________________________________
# batch_normalization_244 (BatchN (None, 93, 92, 128)  512         conv2d_170[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_170 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_244[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_245 (BatchN (None, 93, 92, 256)  1024        conv2d_171[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_171 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_245[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_74 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_243[0][0]
#                                                                  tf.nn.leaky_relu_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_246 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_74[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_246[0][0]
# __________________________________________________________________________________________________
# batch_normalization_247 (BatchN (None, 93, 92, 128)  512         conv2d_172[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_172 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_247[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_248 (BatchN (None, 93, 92, 256)  1024        conv2d_173[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_173 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_248[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_75 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_246[0][0]
#                                                                  tf.nn.leaky_relu_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_249 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_75[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_249[0][0]
# __________________________________________________________________________________________________
# batch_normalization_250 (BatchN (None, 93, 92, 128)  512         conv2d_174[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_174 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_250[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_174[0][0]
# __________________________________________________________________________________________________
# batch_normalization_251 (BatchN (None, 93, 92, 256)  1024        conv2d_175[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_175 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_251[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_76 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_249[0][0]
#                                                                  tf.nn.leaky_relu_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_76[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 93, 92, 128)  512         conv2d_176[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_176 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 93, 92, 256)  1024        conv2d_177[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_177 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_77 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_252[0][0]
#                                                                  tf.nn.leaky_relu_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_77[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 93, 92, 128)  512         conv2d_178[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_178 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 93, 92, 256)  1024        conv2d_179[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_179 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_78 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_255[0][0]
#                                                                  tf.nn.leaky_relu_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_78[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 93, 92, 128)  32768       batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 93, 92, 128)  512         conv2d_180[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_180 (TFOpLambd (None, 93, 92, 128)  0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 93, 92, 256)  294912      tf.nn.leaky_relu_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 93, 92, 256)  1024        conv2d_181[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_181 (TFOpLambd (None, 93, 92, 256)  0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_79 (TFOpLa (None, 93, 92, 256)  0           batch_normalization_258[0][0]
#                                                                  tf.nn.leaky_relu_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 93, 92, 256)  1024        tf.__operators__.add_79[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 94, 93, 256)  0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 46, 46, 512)  1179648     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 46, 46, 512)  2048        conv2d_182[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_182 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 46, 46, 256)  131072      tf.nn.leaky_relu_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 46, 46, 256)  1024        conv2d_183[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_183 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 46, 46, 512)  2048        conv2d_184[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_184 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_80 (TFOpLa (None, 46, 46, 512)  0           tf.nn.leaky_relu_182[0][0]
#                                                                  tf.nn.leaky_relu_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_80[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 46, 46, 256)  1024        conv2d_185[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_185 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 46, 46, 512)  2048        conv2d_186[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_186 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_81 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_265[0][0]
#                                                                  tf.nn.leaky_relu_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_81[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 46, 46, 256)  1024        conv2d_187[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_187 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 46, 46, 512)  2048        conv2d_188[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_188 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_82 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_268[0][0]
#                                                                  tf.nn.leaky_relu_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_82[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 46, 46, 256)  1024        conv2d_189[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_189 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 46, 46, 512)  2048        conv2d_190[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_190 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_83 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_271[0][0]
#                                                                  tf.nn.leaky_relu_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_83[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 46, 46, 256)  1024        conv2d_191[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_191 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 46, 46, 512)  2048        conv2d_192[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_192 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_84 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_274[0][0]
#                                                                  tf.nn.leaky_relu_192[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_84[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 46, 46, 256)  1024        conv2d_193[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_193 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 46, 46, 512)  2048        conv2d_194[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_194 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_85 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_277[0][0]
#                                                                  tf.nn.leaky_relu_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_85[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# batch_normalization_281 (BatchN (None, 46, 46, 256)  1024        conv2d_195[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_195 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_281[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_195[0][0]
# __________________________________________________________________________________________________
# batch_normalization_282 (BatchN (None, 46, 46, 512)  2048        conv2d_196[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_196 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_86 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_280[0][0]
#                                                                  tf.nn.leaky_relu_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_86[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 46, 46, 256)  131072      batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 46, 46, 256)  1024        conv2d_197[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_197 (TFOpLambd (None, 46, 46, 256)  0           batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 46, 46, 512)  1179648     tf.nn.leaky_relu_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 46, 46, 512)  2048        conv2d_198[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_198 (TFOpLambd (None, 46, 46, 512)  0           batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_87 (TFOpLa (None, 46, 46, 512)  0           batch_normalization_283[0][0]
#                                                                  tf.nn.leaky_relu_198[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 46, 46, 512)  2048        tf.__operators__.add_87[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 47, 47, 512)  0           batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 23, 23, 1024) 4718592     zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 23, 23, 1024) 4096        conv2d_199[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_199 (TFOpLambd (None, 23, 23, 1024) 0           batch_normalization_287[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 23, 23, 512)  524288      tf.nn.leaky_relu_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_288 (BatchN (None, 23, 23, 512)  2048        conv2d_200[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_200 (TFOpLambd (None, 23, 23, 512)  0           batch_normalization_288[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 23, 23, 1024) 4718592     tf.nn.leaky_relu_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_289 (BatchN (None, 23, 23, 1024) 4096        conv2d_201[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_201 (TFOpLambd (None, 23, 23, 1024) 0           batch_normalization_289[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_88 (TFOpLa (None, 23, 23, 1024) 0           tf.nn.leaky_relu_199[0][0]
#                                                                  tf.nn.leaky_relu_201[0][0]
# __________________________________________________________________________________________________
# batch_normalization_290 (BatchN (None, 23, 23, 1024) 4096        tf.__operators__.add_88[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 23, 23, 512)  524288      batch_normalization_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_291 (BatchN (None, 23, 23, 512)  2048        conv2d_202[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_202 (TFOpLambd (None, 23, 23, 512)  0           batch_normalization_291[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 23, 23, 1024) 4718592     tf.nn.leaky_relu_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_292 (BatchN (None, 23, 23, 1024) 4096        conv2d_203[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_203 (TFOpLambd (None, 23, 23, 1024) 0           batch_normalization_292[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_89 (TFOpLa (None, 23, 23, 1024) 0           batch_normalization_290[0][0]
#                                                                  tf.nn.leaky_relu_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_293 (BatchN (None, 23, 23, 1024) 4096        tf.__operators__.add_89[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 23, 23, 512)  524288      batch_normalization_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_294 (BatchN (None, 23, 23, 512)  2048        conv2d_204[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_204 (TFOpLambd (None, 23, 23, 512)  0           batch_normalization_294[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 23, 23, 1024) 4718592     tf.nn.leaky_relu_204[0][0]
# __________________________________________________________________________________________________
# batch_normalization_295 (BatchN (None, 23, 23, 1024) 4096        conv2d_205[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_205 (TFOpLambd (None, 23, 23, 1024) 0           batch_normalization_295[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_90 (TFOpLa (None, 23, 23, 1024) 0           batch_normalization_293[0][0]
#                                                                  tf.nn.leaky_relu_205[0][0]
# __________________________________________________________________________________________________
# batch_normalization_296 (BatchN (None, 23, 23, 1024) 4096        tf.__operators__.add_90[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 23, 23, 512)  524288      batch_normalization_296[0][0]
# __________________________________________________________________________________________________
# batch_normalization_297 (BatchN (None, 23, 23, 512)  2048        conv2d_206[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_206 (TFOpLambd (None, 23, 23, 512)  0           batch_normalization_297[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 23, 23, 1024) 4718592     tf.nn.leaky_relu_206[0][0]
# __________________________________________________________________________________________________
# batch_normalization_298 (BatchN (None, 23, 23, 1024) 4096        conv2d_207[0][0]
# __________________________________________________________________________________________________
# tf.nn.leaky_relu_207 (TFOpLambd (None, 23, 23, 1024) 0           batch_normalization_298[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_91 (TFOpLa (None, 23, 23, 1024) 0           batch_normalization_296[0][0]
#                                                                  tf.nn.leaky_relu_207[0][0]
# __________________________________________________________________________________________________
# batch_normalization_299 (BatchN (None, 23, 23, 1024) 4096        tf.__operators__.add_91[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_3 (Glo (None, 1024)         0           batch_normalization_299[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          262400      global_average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 256)          65792       dense_9[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 12)           3084        dense_10[0][0]
# ==================================================================================================
# Total params: 40,994,156
# Trainable params: 40,937,324
# Non-trainable params: 56,832
# __________________________________________________________________________________________________
# Epoch 1/200
# 138/138 [==============================] - 54s 360ms/step - loss: 7.5504 - val_loss: 10.8496
# Epoch 2/200
# 138/138 [==============================] - 49s 352ms/step - loss: 4.5773 - val_loss: 19.8973
# Epoch 3/200
# 138/138 [==============================] - 49s 354ms/step - loss: 3.9555 - val_loss: 5.2065
# Epoch 4/200
# 138/138 [==============================] - 48s 351ms/step - loss: 3.6501 - val_loss: 6.3390
# Epoch 5/200
# 138/138 [==============================] - 49s 352ms/step - loss: 3.4070 - val_loss: 10.9707
# Epoch 6/200
# 138/138 [==============================] - 49s 352ms/step - loss: 3.5715 - val_loss: 4.7751
# Epoch 7/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.4099 - val_loss: 3.8552
# Epoch 8/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.4987 - val_loss: 5.3947
# Epoch 9/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.0500 - val_loss: 8.2884
# Epoch 10/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.9544 - val_loss: 6.6831
# Epoch 11/200
# 138/138 [==============================] - 49s 353ms/step - loss: 4.0855 - val_loss: 6.3436
# Epoch 12/200
# 138/138 [==============================] - 49s 352ms/step - loss: 3.1021 - val_loss: 6.1144
# Epoch 13/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.8772 - val_loss: 5.7129
# Epoch 14/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.9055 - val_loss: 5.5950
# Epoch 15/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.0923 - val_loss: 9.3249
# Epoch 16/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.0600 - val_loss: 4.4546
# Epoch 17/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.0600 - val_loss: 5.9871
# Epoch 18/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.0074 - val_loss: 6.0876
# Epoch 19/200
# 138/138 [==============================] - 49s 352ms/step - loss: 2.8408 - val_loss: 6.0637
# Epoch 20/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.8062 - val_loss: 6.6181
# Epoch 21/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.9190 - val_loss: 17.0271
# Epoch 22/200
# 138/138 [==============================] - 49s 353ms/step - loss: 4.3356 - val_loss: 14.0398
# Epoch 23/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.9661 - val_loss: 65.6265
# Epoch 24/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.6701 - val_loss: 5.1069
# Epoch 25/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.4133 - val_loss: 5.6991
# Epoch 26/200
# 138/138 [==============================] - 49s 354ms/step - loss: 3.0426 - val_loss: 5.7359
# Epoch 27/200
# 138/138 [==============================] - 49s 353ms/step - loss: 3.2666 - val_loss: 6.1144
# Epoch 28/200
# 138/138 [==============================] - 49s 355ms/step - loss: 3.1752 - val_loss: 4.6802
# Epoch 29/200
# 138/138 [==============================] - 49s 356ms/step - loss: 2.7905 - val_loss: 7.4887
# Epoch 30/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.8452 - val_loss: 5.6898
# Epoch 31/200
# ...
# Epoch 50/200
# 138/138 [==============================] - 50s 364ms/step - loss: 3.1532 - val_loss: 5.7166
# Epoch 51/200
# 138/138 [==============================] - 49s 358ms/step - loss: 2.6136 - val_loss: 4.7247
# Epoch 52/200
# 138/138 [==============================] - 49s 355ms/step - loss: 2.4405 - val_loss: 3.1361
# Epoch 53/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.5183 - val_loss: 3.7461
# Epoch 54/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.5428 - val_loss: 2.4296
# Epoch 55/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.4655 - val_loss: 5.9224
# Epoch 56/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.5969 - val_loss: 3.4615
# Epoch 57/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.4500 - val_loss: 4.5795
# Epoch 58/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.2487 - val_loss: 2.9594
# Epoch 59/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.5509 - val_loss: 12.7027
# Epoch 60/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.4136 - val_loss: 4.4216
# Epoch 61/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.6518 - val_loss: 9.6581
# Epoch 62/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.3603 - val_loss: 5.3199
# Epoch 63/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.0924 - val_loss: 5.7950
# Epoch 64/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.3817 - val_loss: 3.1313
# Epoch 65/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.5233 - val_loss: 6.5900
# Epoch 66/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.2717 - val_loss: 5.4232
# Epoch 67/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.1077 - val_loss: 5.5620
# Epoch 68/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.9570 - val_loss: 3.0675
# Epoch 69/200
# 138/138 [==============================] - 49s 355ms/step - loss: 2.2896 - val_loss: 7.3387
# Epoch 70/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.3340 - val_loss: 6.7897
# Epoch 71/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.0836 - val_loss: 3.7833
# Epoch 72/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.4260 - val_loss: 5.2236
# Epoch 73/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.0753 - val_loss: 4.6205
# Epoch 74/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.2091 - val_loss: 6.8527
# Epoch 75/200
# 138/138 [==============================] - 49s 355ms/step - loss: 2.2172 - val_loss: 4.3947
# Epoch 76/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.3825 - val_loss: 6.6768
# Epoch 77/200
# 138/138 [==============================] - 49s 355ms/step - loss: 2.1034 - val_loss: 3.5782
# Epoch 78/200
# 138/138 [==============================] - 49s 355ms/step - loss: 2.1609 - val_loss: 2.4905
# Epoch 79/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.3051 - val_loss: 4.3224
# Epoch 80/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.2758 - val_loss: 57.0673
# Epoch 81/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.7958 - val_loss: 3.7052
# Epoch 82/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.4216 - val_loss: 7.1325
# Epoch 83/200
# 138/138 [==============================] - 49s 357ms/step - loss: 2.0447 - val_loss: 6503.6519
# Epoch 84/200
# 138/138 [==============================] - 49s 356ms/step - loss: 2.9059 - val_loss: 7.1791
# Epoch 85/200
# 138/138 [==============================] - 49s 357ms/step - loss: 2.3617 - val_loss: 5.1256
# Epoch 86/200
# 138/138 [==============================] - 49s 356ms/step - loss: 2.1684 - val_loss: 4.7224
# Epoch 87/200
# 138/138 [==============================] - 50s 361ms/step - loss: 2.0887 - val_loss: 2.7019
# Epoch 88/200
# 138/138 [==============================] - 50s 361ms/step - loss: 2.2123 - val_loss: 2.5361
# Epoch 89/200
# 138/138 [==============================] - 50s 359ms/step - loss: 2.0474 - val_loss: 7.0332
# Epoch 90/200
# 138/138 [==============================] - 49s 356ms/step - loss: 2.1490 - val_loss: 2.3549
# Epoch 91/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.9764 - val_loss: 2.9427
# Epoch 92/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.0660 - val_loss: 6.7157
# Epoch 93/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9405 - val_loss: 9.9358
# Epoch 94/200
# 138/138 [==============================] - 49s 354ms/step - loss: 2.2435 - val_loss: 6.1053
# Epoch 95/200
# 138/138 [==============================] - 49s 358ms/step - loss: 2.0561 - val_loss: 3.4755
# Epoch 96/200
# 138/138 [==============================] - 49s 358ms/step - loss: 2.0653 - val_loss: 6.1634
# Epoch 97/200
# 138/138 [==============================] - 49s 356ms/step - loss: 1.8971 - val_loss: 5.7889
# Epoch 98/200
# 138/138 [==============================] - 49s 358ms/step - loss: 1.9763 - val_loss: 6.0657
# Epoch 99/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.7725 - val_loss: 4.6819
# Epoch 100/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9454 - val_loss: 2.8995
# Epoch 101/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9548 - val_loss: 2.6927
# Epoch 102/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.8785 - val_loss: 3.2217
# Epoch 103/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9930 - val_loss: 3.6290
# Epoch 104/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.9714 - val_loss: 5.8432
# Epoch 105/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9576 - val_loss: 4.0692
# Epoch 106/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9985 - val_loss: 5.7858
# Epoch 107/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.9242 - val_loss: 6.0274
# Epoch 108/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.9528 - val_loss: 6.7319
# Epoch 109/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.0460 - val_loss: 6.4155
# Epoch 110/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.0351 - val_loss: 5.0555
# Epoch 111/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.8339 - val_loss: 3.7241
# Epoch 112/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.9250 - val_loss: 7.1001
# Epoch 113/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.7965 - val_loss: 6.8069
# Epoch 114/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.9560 - val_loss: 6.3828
# Epoch 115/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.8556 - val_loss: 3.7470
# Epoch 116/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.6953 - val_loss: 6.2643
# Epoch 117/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.0031 - val_loss: 6.7827
# Epoch 118/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.7556 - val_loss: 7.7058
# Epoch 119/200
# 138/138 [==============================] - 49s 353ms/step - loss: 2.0978 - val_loss: 6.5213
# Epoch 120/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.8220 - val_loss: 6.4539
# Epoch 121/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.8086 - val_loss: 3.5245
# Epoch 122/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.7243 - val_loss: 4.3011
# Epoch 123/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.7354 - val_loss: 3.0157
# Epoch 124/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.7044 - val_loss: 3.3332
# Epoch 125/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.8139 - val_loss: 2.6252
# Epoch 126/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.7262 - val_loss: 6.6746
# Epoch 127/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.7581 - val_loss: 6.0560
# Epoch 128/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.6533 - val_loss: 2.3807
# Epoch 129/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.7886 - val_loss: 6.4939
# Epoch 130/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.6836 - val_loss: 12.0830
# Epoch 131/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.9146 - val_loss: 2.2047
# Epoch 132/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.6454 - val_loss: 4.0548
# Epoch 133/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.6666 - val_loss: 6.0465
# Epoch 134/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.6900 - val_loss: 2.8923
# Epoch 135/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.6637 - val_loss: 6.3213
# Epoch 136/200
# 138/138 [==============================] - 49s 353ms/step - loss: 1.6520 - val_loss: 5.3681
# Epoch 137/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.7400 - val_loss: 4.7591
# Epoch 138/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.6407 - val_loss: 3.4804
# Epoch 139/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.5541 - val_loss: 2.2316
# Epoch 140/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.4733 - val_loss: 25.3946
# Epoch 141/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.6883 - val_loss: 4.6768
# Epoch 142/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4801 - val_loss: 6.4979
# Epoch 143/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4809 - val_loss: 6.0825
# Epoch 144/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.3645 - val_loss: 2.8935
# Epoch 145/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.5380 - val_loss: 3.6480
# Epoch 146/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.5408 - val_loss: 799.7766
# Epoch 147/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.6382 - val_loss: 4.2348
# Epoch 148/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.5591 - val_loss: 4.5504
# Epoch 149/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.4590 - val_loss: 2.5938
# Epoch 150/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4961 - val_loss: 2.5329
# Epoch 151/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3863 - val_loss: 6.5047
# Epoch 152/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.5161 - val_loss: 1.7288
# Epoch 153/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.3442 - val_loss: 4.5636
# Epoch 154/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4956 - val_loss: 5.7402
# Epoch 155/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.5139 - val_loss: 2.0307
# Epoch 156/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4098 - val_loss: 1.6625
# Epoch 157/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4127 - val_loss: 2.0077
# Epoch 158/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3280 - val_loss: 2.6161
# Epoch 159/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3897 - val_loss: 2.8108
# Epoch 160/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4083 - val_loss: 4.8869
# Epoch 161/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4118 - val_loss: 1.4600
# Epoch 162/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3978 - val_loss: 2.5853
# Epoch 163/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4713 - val_loss: 3.8558
# Epoch 164/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4167 - val_loss: 4.2686
# Epoch 165/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3847 - val_loss: 3.1355
# Epoch 166/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4277 - val_loss: 1.7556
# Epoch 167/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4102 - val_loss: 5.8436
# Epoch 168/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3781 - val_loss: 4.6138
# Epoch 169/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.5560 - val_loss: 1.7040
# Epoch 170/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4082 - val_loss: 3.4709
# Epoch 171/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3795 - val_loss: 4.5533
# Epoch 172/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2916 - val_loss: 3.9628
# Epoch 173/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3424 - val_loss: 5.2892
# Epoch 174/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3704 - val_loss: 3.7976
# Epoch 175/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.5144 - val_loss: 1.4462
# Epoch 176/200
# 138/138 [==============================] - 49s 355ms/step - loss: 1.2625 - val_loss: 9.8294
# Epoch 177/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2782 - val_loss: 6.3176
# Epoch 178/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4369 - val_loss: 1.9118
# Epoch 179/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4593 - val_loss: 2.9144
# Epoch 180/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3592 - val_loss: 4.9481
# Epoch 181/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3009 - val_loss: 3.8706
# Epoch 182/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3123 - val_loss: 4.1991
# Epoch 183/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3676 - val_loss: 7.1907
# Epoch 184/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3657 - val_loss: 5.8394
# Epoch 185/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.6719 - val_loss: 2.5611
# Epoch 186/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.4077 - val_loss: 4.0049
# Epoch 187/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3919 - val_loss: 1.7497
# Epoch 188/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3596 - val_loss: 2.7931
# Epoch 189/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2952 - val_loss: 4.0281
# Epoch 190/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2959 - val_loss: 3.1322
# Epoch 191/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2611 - val_loss: 4.7434
# Epoch 192/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2524 - val_loss: 1.8853
# Epoch 193/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3455 - val_loss: 5.2888
# Epoch 194/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3941 - val_loss: 2.5061
# Epoch 195/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2758 - val_loss: 5.1820
# Epoch 196/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3253 - val_loss: 3.0867
# Epoch 197/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3728 - val_loss: 5.7658
# Epoch 198/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.3540 - val_loss: 1.6104
# Epoch 199/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.2641 - val_loss: 1.9105
# Epoch 200/200
# 138/138 [==============================] - 49s 354ms/step - loss: 1.1816 - val_loss: 1.4772

# %%
Save_history = Model_history.history
Save_history = pd.DataFrame(Save_history)
writer = pd.ExcelWriter('C:/Users/Administrator/Desktop/surface/实验结果存放/Darknet53_conv2D_loss.xlsx')  #关键2，创建名称为hhh的excel表格
Save_history.to_excel(writer,'page_1',float_format='%.5f')  #关键3，float_format 控制精度，将data_df写到hhh表格的第一页中。若多个文件，可以在page_2中写入
writer.save()

# %%
############Test性能测试###################
def identification(predicted_gradient,real_gradient,threshold):
    AC13=[0,6,4,3.5,5.5,7.5,10.5,16,23.5,18.5,5,0]#级配
    AC16=[0,5.4,2.4,2.4,3.7,4.1,7.8,5.5,26.3,20.1,16.6,5.7]#级配 
    SMA13=[0,10.7,2.1,1.4,1.1,1.2,2.9,9.4,30.3,31.5,8.2,1.2]#级配
    UT5=[0,6.7,2,2.5,5,20,13.4,48.8,1.5,0.1,0,0]#级配
    OGFC10=[0,4,1.5,2,2,2.5,4,44,35,5,0,0]#级配
    if np.average(np.abs(real_gradient-AC13))==0:
        Real_result=0
    elif np.average(np.abs(real_gradient-AC16))==0:
        Real_result=1
    elif np.average(np.abs(real_gradient-SMA13))==0:
        Real_result=2
    elif np.average(np.abs(real_gradient-UT5))==0:
        Real_result=3
    elif np.average(np.abs(real_gradient-OGFC10))==0:
        Real_result=4
        
    R_AC13=np.average(np.abs(predicted_gradient-AC13))
    R_AC16=np.average(np.abs(predicted_gradient-AC16))
    R_SMA13=np.average(np.abs(predicted_gradient-SMA13))
    R_UT5=np.average(np.abs(predicted_gradient-UT5))
    R_OGFC10=np.average(np.abs(predicted_gradient-OGFC10))
    
    Predicted_result =np.argmin(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))
    
    if np.min(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))>threshold:
        Predicted_result = 5
    
    return Real_result, Predicted_result

n_classes = 12
Batch_size=4
input_tensor = tf.keras.layers.Input([750, 740, 3])
conv_tensors = Darknet53(input_tensor,num_classes=12)
model = tf.keras.Model(input_tensor, conv_tensors)
model.load_weights("Darknet53.h5")
model.compile(optimizer=keras.optimizers.Adam(lr), loss=tf.keras.losses.MAE)
model.evaluate(Test_X_Data,Test_Y_Data)
Thr_list = [0.1,0.5,1,1.5,2,2.5,3]
for Thr in Thr_list:
    Real_result = []
    Predicted_result = []
    for i in range(len(Test_X_Data)):
        R,P=identification(model(np.array(Test_X_Data[i])[np.newaxis,...])[0],Test_Y_Data[i],Thr)
        Real_result.append(R)
        Predicted_result.append(P)
    #######绘制混淆矩阵################
    C = confusion_matrix(Real_result, Predicted_result, labels=[0,1,2,3,4,5]) 
    plt.matshow(C, cmap=plt.cm.Blues) # 根据最下面的图按自己需求更改颜色
    plt.colorbar()
    for i in range(len(C)):
        for j in range(len(C)):
            plt.annotate(C[j, i], xy=(i, j), horizontalalignment='center', verticalalignment='center')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.xticks(range(0,6), labels=['AC13','AC16','SMA13','UT5','OGFC10','Other'], rotation=20) # 将x轴或y轴坐标，刻度 替换为文字/字符
    plt.yticks(range(0,6), labels=['AC13','AC16','SMA13','UT5','OGFC10','Other'])
    plt.savefig('C:/Users/Administrator/Desktop/surface/实验结果存放/Darknet53_conv2D'+str(Thr)+'.png',dpi=600)#保存图片
    plt.show()
# Out:
# 7/7 [==============================] - 3s 296ms/step - loss: 1.3155
