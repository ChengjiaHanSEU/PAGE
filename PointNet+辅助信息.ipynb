# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
import numpy as np
import math
import sys
import os
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt
from plyfile import *
from mpl_toolkits.mplot3d import Axes3D
import open3d as o3d 
import numpy as np
import scipy.stats
import random
import pandas as pd
from sklearn.metrics import confusion_matrix
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
#点云文件导入
##############导入点云数据#################
pcd_AC13_1 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC13-1.ply")
pcd_AC13_2 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC13-2.ply")
pcd_AC16_3 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC16-3.ply")
pcd_AC16_4 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC16-4.ply")
pcd_UT5_1  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-1.ply")
pcd_UT5_2  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-2.ply")
pcd_UT5_3  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-3.ply")
pcd_UT5_4  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-4.ply")
pcd_SMA13_1= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/SMA13-1.ply")
pcd_SMA13_2= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/SMA13-2.ply")
pcd_OGFC10_1= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/OGFC10-1.ply")
#############点云标准化####################
def standard_pointcloud(point_cloud):
    Point_standard=[]
    Point=np.asarray(point_cloud.points)    
    x=np.array(Point[:,0])[...,np.newaxis]
    y=np.array(Point[:,1])[...,np.newaxis]
    z=np.array(Point[:,2])[...,np.newaxis]
    Point_standard=np.concatenate((x-np.min(x),y-np.min(y),z-np.min(z)),axis=-1)
    return Point_standard

AC13_1=standard_pointcloud(pcd_AC13_1)
AC13_2=standard_pointcloud(pcd_AC13_2)
AC16_3=standard_pointcloud(pcd_AC16_3)
AC16_4=standard_pointcloud(pcd_AC16_4)
UT5_1=standard_pointcloud(pcd_UT5_1)
UT5_2=standard_pointcloud(pcd_UT5_2)
UT5_3=standard_pointcloud(pcd_UT5_3)
UT5_4=standard_pointcloud(pcd_UT5_4)
SMA13_1= standard_pointcloud(pcd_SMA13_1)
SMA13_2= standard_pointcloud(pcd_SMA13_2)
OGFC10_1 =  standard_pointcloud(pcd_OGFC10_1)

point_cloud_array_group = []
point_cloud_array_group.append(AC13_1)
point_cloud_array_group.append(AC13_2)
point_cloud_array_group.append(AC16_3)
point_cloud_array_group.append(AC16_4)
point_cloud_array_group.append(UT5_1)
point_cloud_array_group.append(UT5_2)
point_cloud_array_group.append(UT5_3)
point_cloud_array_group.append(UT5_4)
point_cloud_array_group.append(SMA13_1)
point_cloud_array_group.append(SMA13_2)
point_cloud_array_group.append(OGFC10_1)
#############点云标准化####################
def standard_pointcloud(point_cloud):
    Point_standard=[]  
    x=np.array(point_cloud[:,0])[...,np.newaxis]
    y=np.array(point_cloud[:,1])[...,np.newaxis]
    z=np.array(point_cloud[:,2])[...,np.newaxis]
    Point_standard=np.concatenate((x-np.min(x),y-np.min(y),z-np.min(z)),axis=-1)
    return Point_standard
######################按照计算的H_final进行窗口滑动切分#########################
H_final=51
AC13=[0,6,4,3.5,5.5,7.5,10.5,16,23.5,18.5,5,0]#级配
AC16=[0,5.4,2.4,2.4,3.7,4.1,7.8,5.5,26.3,20.1,16.6,5.7]#级配 
SMA13=[0,10.7,2.1,1.4,1.1,1.2,2.9,9.4,30.3,31.5,8.2,1.2]#级配
UT5=[0,6.7,2,2.5,5,20,13.4,48.8,1.5,0.1,0,0]#级配
OGFC10=[0,4,1.5,2,2,2.5,4,44,35,5,0,0]#级配
def split_slide(point_cloud_array_origion,H_new=H_final, intervial =[5,5]):
    L=int(np.max(point_cloud_array_origion[:,0]))
    W=int(np.max(point_cloud_array_origion[:,1]))
    Point_cloud_small = []
    L_intervial = intervial[0]
    W_intervial = intervial[1]
    for i in range (0,L-H_new,L_intervial):
        for j in range (0,W-H_new,W_intervial):
            temp_point_cloud = point_cloud_array_origion[np.where((point_cloud_array_origion[:,1]>i)&
                                                                  (point_cloud_array_origion[:,1]<(H_new+i))&
                                                                  (point_cloud_array_origion[:,0]>j)&
                                                                  (point_cloud_array_origion[:,0]<(H_new+j)))]
            temp_point_cloud = standard_pointcloud(temp_point_cloud)
            Point_cloud_small.append(temp_point_cloud)
    return Point_cloud_small
####################原始图像拆分子点云集########################################
PointCloud_new =[]
#制作Ground truth
Y_Data=np.zeros((1,12))
###################辅助信息###########################
F_AC13_1 =[1.24,0.63,0.51,-0.48,3.61,-2.33,-0.41,-0.07,0.16,0.42,1.68,0.87]
F_AC13_2 =[1.26,0.59,0.45,-0.56,3.58,-1.96,-0.33,-0.03,0.18,0.39,1.72,0.91]
F_AC16_3 =[0.92,0.77,0.76,-0.93,4.06,-3.38,-0.49, 0.02,0.36,0.68,1.28,0.93]
F_AC16_4 =[1.27,0.87,0.96,-0.75,3.74,-4.47,-0.64,-0.04,0.45,0.90,1.78,1.04]
F_UT5_1  =[0.49,0.54,0.39,-1.44,7.12,-3.55,-0.17, 0.06,0.21,0.34,0.72,0.63]
F_UT5_2  =[0.53,0.56,0.40,-1.13,5.12,-2.49,-0.24, 0.03,0.21,0.35,0.75,0.71]
F_UT5_3  =[0.49,0.54,0.39,-1.44,7.12,-3.55,-0.17, 0.06,0.21,0.34,0.72,0.63]
F_UT5_4  =[0.53,0.56,0.40,-1.13,5.12,-2.49,-0.24, 0.03,0.21,0.35,0.75,0.71]
F_SMA13_1=[1.33,1.04,1.35,-0.93,4.07,-6.09,-0.63, 0.30,0.82,1.28,2.05,0.95]
F_SMA13_2=[1.42,1.00,1.29,-1.33,5.75,-7.60,-0.74, 0.17,0.71,1.12,2.05,1.05]
F_OGFC10 =[1.77,0.77,0.75,-0.97,4.77,-4.47,-0.44, 0.08,0.39,0.66,2.41,1.52]
Aided_information = np.zeros((1,12))
for i in range(11):
    temp=split_slide(point_cloud_array_group[i])
    #print(len(temp))
    PointCloud_new=np.concatenate((PointCloud_new,temp),axis=0)
    if (i==0): 
        temp2 = np.full((len(temp),12),AC13)
        temp3 = np.full((len(temp),12),F_AC13_1)
    elif (i==1):
        temp2 = np.full((len(temp),12),AC13)
        temp3 = np.full((len(temp),12),F_AC13_2)
    elif (i==2):
        temp2 = np.full((len(temp),12),AC16)
        temp3 = np.full((len(temp),12),F_AC16_3)
    elif (i==3):
        temp2 = np.full((len(temp),12),AC16)
        temp3 = np.full((len(temp),12),F_AC16_4)
    elif (i==4):
        temp2 = np.full((len(temp),12),UT5)
        temp3 = np.full((len(temp),12),F_UT5_1)
    elif (i==5):
        temp2 = np.full((len(temp),12),UT5)
        temp3 = np.full((len(temp),12),F_UT5_2)
    elif (i==6):
        temp2 = np.full((len(temp),12),UT5)
        temp3 = np.full((len(temp),12),F_UT5_3)
    elif (i==7):
        temp2 = np.full((len(temp),12),UT5)
        temp3 = np.full((len(temp),12),F_UT5_4)
    elif (i==8):
        temp2 = np.full((len(temp),12),SMA13)
        temp3 = np.full((len(temp),12),F_SMA13_1)
    elif (i==9):
        temp2 = np.full((len(temp),12),SMA13)
        temp3 = np.full((len(temp),12),F_SMA13_2)     
    elif (i==10):
        temp2 = np.full((len(temp),12),OGFC10)
        temp3 = np.full((len(temp),12),F_OGFC10)  
    #print(temp2.shape)
    Y_Data = np.concatenate((Y_Data,temp2),axis=0)
    Aided_information = np.concatenate((Aided_information,temp3),axis=0)
    #print(np.array(Y_Data).shape)
Y_Data = np.delete(Y_Data, 1, 0)#把第一行0删掉
Aided_information = np.delete(Aided_information, 1, 0)#把第一行0删掉
print(Y_Data.shape)
print(Aided_information.shape)
#print(len(PointCloud_new))
#计算最小子点云点数
num_min=PointCloud_new[0].shape[0]
for i in range(len(PointCloud_new)):
    num_point = PointCloud_new[i].shape[0]
    if num_min>num_point:
        num_min = num_point
#print(num_min)
#根据最小点云数进行降采样，根据设置的点数降采样
def pointCloud_downsampling(Point_cloud_array, num_pointCloud=30000):
    # estimate radius for rolling ball
    pcd=o3d.geometry.PointCloud()
    pcd.points=o3d.utility.Vector3dVector(Point_cloud_array)
    pcd.estimate_normals()
    # estimate radius for rolling ball
    distances = pcd.compute_nearest_neighbor_distance()
    avg_dist = np.mean(distances)
    radius = 1.5 * avg_dist   
    mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(pcd,o3d.utility.DoubleVector([radius, radius * 2]))
    pcd_new = o3d.geometry.TriangleMesh.sample_points_uniformly(mesh, number_of_points=num_pointCloud) # 采样点云
    #o3d.visualization.draw_geometries([pcd_new],width=1024, height=1024)
    New_Point_cloud_array = np.asarray(pcd_new.points)
    return New_Point_cloud_array

PointCloud_Standard =[]
for i in range(len(PointCloud_new)):
    PointCloud_Standard.append(pointCloud_downsampling(PointCloud_new[i],6000))
print(np.array(PointCloud_Standard).shape)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# (1579, 12)
# [[0.   0.   0.   ... 0.   0.   0.  ]
#  [1.24 0.63 0.51 ... 0.42 1.68 0.87]
#  [1.24 0.63 0.51 ... 0.42 1.68 0.87]
#  ...
#  [1.77 0.77 0.75 ... 0.66 2.41 1.52]
#  [1.77 0.77 0.75 ... 0.66 2.41 1.52]
#  [1.77 0.77 0.75 ... 0.66 2.41 1.52]]
# (1579, 6000, 3)

# %%
#### 数据集1579分，切分为1379训练 200测试#######################
arr = np.array(range(0, 1579, 1))
r = np.random.permutation(arr)
Train_X1_Data = []
Train_X2_Data = []
Train_Y_Data = []
for i in range(1379):
    Train_X1_Data.append(PointCloud_Standard[r[i]])
    Train_X2_Data.append(Aided_information[r[i]])
    Train_Y_Data.append(Y_Data[r[i]])

Test_X1_Data = []
Test_X2_Data = []
Test_Y_Data = []
for i in range(1379,1579):
    Test_X1_Data.append(PointCloud_Standard[r[i]])
    Test_X2_Data.append(Aided_information[r[i]])
    Test_Y_Data.append(Y_Data[r[i]])
    
Train_X1_Data = np.array(Train_X1_Data)
Train_X2_Data = np.array(Train_X2_Data)
Train_Y_Data = np.array(Train_Y_Data)
Test_X1_Data = np.array(Test_X1_Data)
Test_X2_Data = np.array(Test_X2_Data)
Test_Y_Data = np.array(Test_Y_Data)

print(Train_X1_Data.shape)
print(Train_X2_Data.shape)
print(Train_Y_Data.shape)
print(Test_X1_Data.shape)
print(Test_X2_Data.shape)
print(Test_Y_Data.shape)
# Out:
# (1379, 6000, 3)
# (1379, 12)
# (1379, 12)
# (200, 6000, 3)
# (200, 12)
# (200, 12)

# %%
class CustomConvolution(keras.layers.Layer):
    def __init__(self, filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID', bn_momentum=0.99,
                 activation=None, apply_bn=False):
        super(CustomConvolution, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.bn_momentum = bn_momentum
        self.activation = activation
        self.convolution = keras.layers.Conv2D(filters, kernel_size, strides, padding)
        self.apply_bn = apply_bn
        if self.apply_bn:
            self.bn = keras.layers.BatchNormalization(momentum=bn_momentum)

    def call(self, inputs, training=None):
        x = self.convolution(inputs)
        if self.apply_bn:
            x = self.bn(x, training=training)
        if self.activation:
            x = self.activation(x)
        return x

    def get_config(self):
        config = super(CustomConvolution, self).get_config()
        config.update(
            {
                'filters': self.filters,
                'kernel_size': self.kernel_size,
                'strides': self.strides,
                'padding': self.padding,
                'bn_momentum': self.bn_momentum,
                'activation': self.activation,
                'apply_bn': self.apply_bn
            }
        )
    @classmethod
    def from_config(cls, config):
        return cls(**config)

class CustomDense(keras.layers.Layer):
    def __init__(self, units=256, activation=tf.nn.relu, bn_momentum=0.99, apply_bn=False):
        super(CustomDense, self).__init__()
        self.filters = units
        self.bn_momentum = bn_momentum
        self.activation = activation
        self.dense = keras.layers.Dense(units)
        self.apply_bn = apply_bn
        if self.apply_bn:
            self.bn = keras.layers.BatchNormalization(momentum=bn_momentum)

    def call(self, inputs, training=None):
        x = self.dense(inputs)
        if self.apply_bn:
            x = self.bn(x, training=training)
        if self.activation:
            x = self.activation(x)
        return x

    def get_config(self):
        config = super(CustomDense, self).get_config()
        config.update(
            {
                'units': self.units,
                'activation': self.activation,
                'bn_momentum': self.bn_momentum,
                'apply_bn': self.apply_bn
            }
        )

    @classmethod
    def from_config(cls, config):
        return cls(**config)

class input_TransformNet(keras.layers.Layer):
    def __init__(self, add_regularization=False, bn_momentum=0.99, name=None, **kwargs):
        super(input_TransformNet, self).__init__(name=name, **kwargs)
        self.add_regularization = add_regularization
        self.bn_momentum = bn_momentum
        self.conv0 = CustomConvolution(filters=64, kernel_size=(1, 3), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)
        self.conv1 = CustomConvolution(filters=128, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.conv2 = CustomConvolution(filters=1024, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense0 = CustomDense(units=512, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)

    def build(self, input_shape):
        self.K = input_shape[2]
        self.w = self.add_weight(name='w', shape=[256, self.K ** 2], initializer=tf.zeros_initializer, dtype=tf.float32)
        self.b = self.add_weight(name='b', shape=(self.K, self.K), initializer=tf.zeros_initializer, dtype=tf.float32)
        I = tf.constant(np.eye(self.K), dtype=tf.float32)
        self.b = tf.math.add(self.b, I)

    def call(self, inputs, training=None):
        x = inputs  # BxNx3
        x = tf.expand_dims(x, axis=-1)  # BxNx3x1
        x = self.conv0(x, training=training)  # BxNx1x64
        x = self.conv1(x, training=training)  # BxNx1x128
        x = self.conv2(x, training=training)  # BxNx1x1024
        x = tf.squeeze(x, axis=2)  # BxNx1024
        x = tf.reduce_max(x, axis=1)  # Bx1024sss
        x = self.dense0(x, training=training)  # Bx512
        x = self.dense1(x, training=training)  # Bx256

        x = tf.expand_dims(x, axis=1)  # Bx1x256
        x = tf.matmul(x, self.w)  # Bx1xK**2
        x = tf.squeeze(x, axis=1)  # BxK**2
        x = tf.reshape(x, (-1, self.K, self.K))  # BxKxK
        x += self.b

        if self.add_regularization:
            eye = tf.constant(np.eye(self.K), dtype=tf.float32)
            x_transpose = tf.transpose(x, perm=[0, 2, 1])
            x_xt = tf.matmul(x, x_transpose)
            reg = tf.nn.l2_loss(eye - x_xt)
            self.add_loss(1e-3 * reg)

        return tf.matmul(inputs, x)

    def get_config(self):
        config = super(TransformNet, self).get_config()
        config.update(
            {
                'add_regularization': self.add_regularization,
                'bn_momentum': self.bn_momentum,
            }
        )

    @classmethod
    def from_config(cls, config):
        return cls(**config)

class feature_TransformNet(keras.layers.Layer):
    def __init__(self, add_regularization=False, bn_momentum=0.99, name=None, **kwargs):
        super(feature_TransformNet, self).__init__(name=name, **kwargs)
        self.add_regularization = add_regularization
        self.bn_momentum = bn_momentum
        self.conv0 = CustomConvolution(filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)
        self.conv1 = CustomConvolution(filters=128, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.conv2 = CustomConvolution(filters=1024, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense0 = CustomDense(units=512, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)

    def build(self, input_shape):
        self.K = input_shape[-1]
        self.w = self.add_weight(name='w', shape=[256, self.K ** 2], initializer=tf.zeros_initializer, dtype=tf.float32)
        self.b = self.add_weight(name='b', shape=(self.K, self.K), initializer=tf.zeros_initializer, dtype=tf.float32)
        I = tf.constant(np.eye(self.K), dtype=tf.float32)
        self.b = tf.math.add(self.b, I)

    def call(self, inputs, training=None):
        x = inputs  # BxNx1x64
        x = self.conv0(x, training=training)  # BxNx1x64
        x = self.conv1(x, training=training)  # BxNx1x128
        x = self.conv2(x, training=training)  # BxNx1x1024
        x = tf.squeeze(x, axis=2)  # BxNx1024
        x = tf.reduce_max(x, axis=1)  # Bx1024sss
        x = self.dense0(x, training=training)  # Bx512
        x = self.dense1(x, training=training)  # Bx256

        x = tf.expand_dims(x, axis=1)  # Bx1x256
        x = tf.matmul(x, self.w)  # Bx1xK**2
        x = tf.squeeze(x, axis=1)  # BxK**2
        x = tf.reshape(x, (-1, self.K, self.K))  # BxKxK
        x += self.b

        if self.add_regularization:
            eye = tf.constant(np.eye(self.K), dtype=tf.float32)
            x_transpose = tf.transpose(x, perm=[0, 2, 1])
            x_xt = tf.matmul(x, x_transpose)
            reg = tf.nn.l2_loss(eye - x_xt)
            self.add_loss(1e-3 * reg)

        return tf.matmul(tf.squeeze(inputs, axis=2), x) #BxNxK 把第3轴去掉保持维度统一

    def get_config(self):
        config = super(TransformNet, self).get_config()
        config.update(
            {
                'add_regularization': self.add_regularization,
                'bn_momentum': self.bn_momentum,
            }
        )

    @classmethod
    def from_config(cls, config):
        return cls(**config)

def get_model(n_classes,bn_momentum=0.99):
    add_regularization = True
    # Initialize the input layer
    input_layer1 = keras.Input(shape=(None, 3),
                              name='input_points')  # MxNx3 where M is batch size,N is number of points and 3 for channels
    
    input_layer2 = keras.Input(shape=(12),
                              name='aided_information')  #添加辅助信息
    # Input transform layer
    input_transform = input_TransformNet(add_regularization=add_regularization, bn_momentum=bn_momentum,
                                   name='input_transformation')(input_layer1)  # BxNx3 --> BxNx3
    input_transform = tf.expand_dims(input_transform, axis=-1)  # BxNx3 --> BxNx3x1

    shared_layer_1 = CustomConvolution(filters=64, kernel_size=(1, 3), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(input_transform)  # BxNx3x1 --> BxNx1x64
    shared_layer_2 = CustomConvolution(filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(shared_layer_1)  # BxNx1x64 --> BxNx1x64
    #shared_layer_2 = tf.squeeze(shared_layer_2, axis=2) # BxNx1x64 --> BxNx64

    feature_transform = feature_TransformNet(add_regularization=add_regularization, bn_momentum=bn_momentum,
                                             name='feature_transformation')(shared_layer_2)  # BxNx1x64--> BxNx64
    feature_transform = tf.expand_dims(feature_transform, axis=2)  # BxNx64 --> BxNx1x64

    shared_layer_3 = CustomConvolution(filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(feature_transform)  # BxNx1x64 --> BxNx1x64
    shared_layer_4 = CustomConvolution(filters=128, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(shared_layer_3)  # BxNx1x64 --> BxNx1x128
    shared_layer_5 = CustomConvolution(filters=1024, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(shared_layer_4)  # BxNx1x128 --> BxNx1x1024

    shared_layer_5 = tf.squeeze(shared_layer_5, axis=2)  # BxNx1x1024 --> BxNx1024

    global_features = tf.reduce_max(shared_layer_5, axis=1)  # BxNx1024 --> Bx1024

    dense0 = CustomDense(units=512, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(global_features)
    #dense0 = keras.layers.Dropout(0.5)(dense0)
    dense1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(dense0)
    dense2 = keras.layers.Flatten()(dense1)
    
    ##辅助信息直连#############
    denseF1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(input_layer2)
    denseF2 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(denseF1)
    
    #####concate##############
    dense3 =  CustomDense(units=256, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(dense2)
    dense4 = tf.keras.layers.concatenate([dense3,denseF2],axis=-1)
    dense5 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(dense4)
    
    output_layer = keras.layers.Dense(units=n_classes, activation=tf.nn.relu)(dense5)#级配每档的分计筛余比例

    model = keras.Model(inputs=[input_layer1,input_layer2], outputs=output_layer)
    return model

# %%
################网络训练###########################
n_classes = 12
PointNet= get_model(n_classes)
PointNet.summary()
logdir = "./data/log"
lr = 1e-3
#PointNet.load_weights("PointNet.h5")
PointNet.compile(optimizer=keras.optimizers.Adam(lr), 
                 loss=tf.keras.losses.MAE)
Callback = keras.callbacks.ModelCheckpoint("PointNet-辅助信息版.h5", 
                                           monitor='val_loss', 
                                           save_best_only=True, 
                                           save_weights_only=True)
Model_history=PointNet.fit(x=[Train_X1_Data,Train_X2_Data],y=Train_Y_Data,batch_size=16,epochs = 200,validation_split=0.2,callbacks=Callback)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_points (InputLayer)       [(None, None, 3)]    0
# __________________________________________________________________________________________________
# input_transformation (input_Tra (None, None, 3)      807040      input_points[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_8 (TFOpLambda)   (None, None, 3, 1)   0           input_transformation[0][0]
# __________________________________________________________________________________________________
# custom_convolution_53 (CustomCo (None, None, 1, 64)  512         tf.expand_dims_8[0][0]
# __________________________________________________________________________________________________
# custom_convolution_54 (CustomCo (None, None, 1, 64)  4416        custom_convolution_53[0][0]
# __________________________________________________________________________________________________
# feature_transformation (feature (None, None, 64)     1857216     custom_convolution_54[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_9 (TFOpLambda)   (None, None, 1, 64)  0           feature_transformation[0][0]
# __________________________________________________________________________________________________
# custom_convolution_58 (CustomCo (None, None, 1, 64)  4416        tf.expand_dims_9[0][0]
# __________________________________________________________________________________________________
# custom_convolution_59 (CustomCo (None, None, 1, 128) 8832        custom_convolution_58[0][0]
# __________________________________________________________________________________________________
# custom_convolution_60 (CustomCo (None, None, 1, 1024 136192      custom_convolution_59[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.squeeze_4 (TFOpLam (None, None, 1024)   0           custom_convolution_60[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_max_4 (TFOpLambd (None, 1024)         0           tf.compat.v1.squeeze_4[0][0]
# __________________________________________________________________________________________________
# custom_dense_45 (CustomDense)   (None, 512)          526848      tf.math.reduce_max_4[0][0]
# __________________________________________________________________________________________________
# custom_dense_46 (CustomDense)   (None, 256)          132352      custom_dense_45[0][0]
# __________________________________________________________________________________________________
# aided_information (InputLayer)  [(None, 12)]         0
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 256)          0           custom_dense_46[0][0]
# __________________________________________________________________________________________________
# custom_dense_47 (CustomDense)   (None, 256)          4352        aided_information[0][0]
# __________________________________________________________________________________________________
# custom_dense_49 (CustomDense)   (None, 256)          66816       flatten_4[0][0]
# __________________________________________________________________________________________________
# custom_dense_48 (CustomDense)   (None, 256)          66816       custom_dense_47[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512)          0           custom_dense_49[0][0]
#                                                                  custom_dense_48[0][0]
# __________________________________________________________________________________________________
# custom_dense_50 (CustomDense)   (None, 256)          132352      concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 12)           3084        custom_dense_50[0][0]
# ==================================================================================================
# Total params: 3,751,244
# Trainable params: 3,737,036
# Non-trainable params: 14,208
# __________________________________________________________________________________________________
# Epoch 1/200
# 69/69 [==============================] - 13s 109ms/step - loss: 7.0617 - val_loss: 7.4483
# Epoch 2/200
# 69/69 [==============================] - 7s 99ms/step - loss: 3.3561 - val_loss: 5.3266
# Epoch 3/200
# 69/69 [==============================] - 7s 99ms/step - loss: 2.1176 - val_loss: 3.2320
# Epoch 4/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.3316 - val_loss: 1.8952 loss: 1.
# Epoch 5/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8651 - val_loss: 1.2811
# Epoch 6/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7876 - val_loss: 1.1794: 0.7 - ETA: 0s - loss
# Epoch 7/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9902 - val_loss: 6.5191TA: 5s - loss: 1.2 - ETA: 5s - loss: 1  - ETA: 0s - loss: 0.
# Epoch 8/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8357 - val_loss: 1.6054TA: 2 - ETA: 1s - loss - ETA: 0s - loss: 0.844 - ETA: 0s - loss: 0
# Epoch 9/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7757 - val_loss: 7.7338 3s - - E
# Epoch 10/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7585 - val_loss: 0.9251: 2s - loss: 0.79 - ETA: 2s - ETA: 0s - loss: 0.7 - ETA: 0s - loss: 0
# Epoch 11/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.6727 - val_loss: 25584.9277ETA: 1s - loss: 0.654 - ETA: 1s - loss: 0.65 - ETA: 1s -  - ETA: 0s - loss: 0.
# Epoch 12/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8111 - val_loss: 0.5148TA: 2s - loss:
# Epoch 13/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7802 - val_loss: 0.4128
# Epoch 14/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.5922 - val_loss: 452.9854TA:  - ETA: 1s - l - ETA: 0s - lo
# Epoch 15/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.6935 - val_loss: 36379.88282 - ETA: 2s - loss: 0 - ETA:  - ETA: 0s - los
# Epoch 16/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.6011 - val_loss: 39.2409
# Epoch 17/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.5793 - val_loss: 7.1529ETA: 2s - ETA: 1s - los - ETA: 0s - loss
# Epoch 18/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.5677 - val_loss: 1.1298
# Epoch 19/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.5564 - val_loss: 12.8847: 4s - loss: 0.460 - ETA: 4s - loss: 0. - ETA: 1s - ETA: 0s - loss: 0
# Epoch 20/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.7052 - val_loss: 55689332.0000 - ETA: 1s - loss: 0.657 - ETA: 1s - loss: - ETA: 1s - loss: 0.6 - ETA: 0s - loss - ETA: 0s - loss: 0.70
# Epoch 21/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.7160 - val_loss: 15106.7754
# Epoch 22/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.5397 - val_loss: 311.6803
# Epoch 23/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.6500 - val_loss: 6.6779 0s - loss: 0.651
# Epoch 24/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.5669 - val_loss: 4.3355TA: 0s - loss: 0
# Epoch 25/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.6135 - val_loss: 0.5743 4s - los - ETA: 4s - loss: 0.625 - ETA:
# Epoch 26/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.5280 - val_loss: 0.3089A: 1s
# Epoch 27/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.4849 - val_loss: 46.9527: 5s - lo - ETA: 4s - loss: 0.4 - ETA: 4s - loss: 0.47 - ETA: 4 - ETA: 0s - loss: 0.
# Epoch 28/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.4948 - val_loss: 0.6896 ETA: 1s - l - ETA: 0s - l
# Epoch 29/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.6146 - val_loss: 0.3226 3s - loss: 0.6 - ETA: 3s - loss:  - ETA:  - ETA: 0s - l
# Epoch 30/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.4973 - val_loss: 0.6260
# Epoch 31/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.4396 - val_loss: 0.3772
# Epoch 32/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.4548 - val_loss: 1.1792 ETA: 3s
# Epoch 33/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.3655 - val_loss: 1.4618
# Epoch 34/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.3573 - val_loss: 102.9413 ETA: 0s - lo
# Epoch 35/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.4100 - val_loss: 6.0600loss: 0.391
# Epoch 36/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3812 - val_loss: 0.4137 - loss: - ETA: 4 - ETA: 2s - loss: - ETA: 2s - loss: - ETA: 1
# Epoch 37/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3755 - val_loss: 0.5475s - loss: 0 - ETA: 0s - loss - ETA: 0s - loss: 0.374
# Epoch 38/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3905 - val_loss: 4.4699: 5s - loss: 0. - ETA: 4s - ETA: 3s - loss: 0. - ETA: 0s - los
# Epoch 39/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.3915 - val_loss: 1.5254
# Epoch 40/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.4259 - val_loss: 2.7071
# Epoch 41/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.3925 - val_loss: 3.0800
# Epoch 42/200
# 69/69 [==============================] - 7s 106ms/step - loss: 0.4484 - val_loss: 5.1375TA: 0s - loss:
# Epoch 43/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.3980 - val_loss: 4.8848
# Epoch 44/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.3658 - val_loss: 6.6039
# Epoch 45/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3708 - val_loss: 4.9026ETA: -
# Epoch 46/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.5726 - val_loss: 6037.9780ETA: 3s - loss: 0.4 - ETA: 2s - loss: - ETA: 2s - lo - ETA: 1s - loss: - ETA: 0s - loss:
# Epoch 47/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.4262 - val_loss: 3.5127ETA: 2s - lo - ETA: 1s -  - ETA: 0s - loss: 0
# Epoch 48/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3766 - val_loss: 5.5207 - ETA: 1s - - ETA: 0s - loss: 0
# Epoch 49/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.3949 - val_loss: 7.1164
# Epoch 50/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.5533 - val_loss: 0.4972
# Epoch 51/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.4706 - val_loss: 40.0103
# Epoch 52/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.4795 - val_loss: 1.1987
# Epoch 53/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.3596 - val_loss: 2.3142
# Epoch 54/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.9020 - val_loss: 0.6842
# Epoch 55/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.4417 - val_loss: 0.3611
# Epoch 56/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.4258 - val_loss: 0.4012
# Epoch 57/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.3233 - val_loss: 0.3662 ETA: 1s - loss: - ETA: 0s - loss: 0. - ETA: 0s - loss: 0.323
# Epoch 58/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.3819 - val_loss: 0.3761 - l - ETA: 4s -  - ETA: 3s -
# Epoch 59/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.4514 - val_loss: 0.3640: 1s - loss: 0 - ETA: 1s - loss: 0.4 - ETA: 0s - loss: 0.450 - ETA: 0s - loss
# Epoch 60/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3568 - val_loss: 0.2512 - ETA: 3s - loss: 0. - ETA: 3s - loss: 0. - ETA: 2s - loss: 0 - ETA: 2s - loss: 0 - ETA: 1s - - ETA: 0s - loss: - ETA: 0s - loss: 0.356
# Epoch 61/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.4432 - val_loss: 4.5397- ETA: 1s - loss: 0. - ETA: 1s - loss: 0. - ETA: 1s  - ETA: 0s - loss: 0.441
# Epoch 62/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.4485 - val_loss: 1.1227TA: 4s - loss: 0.44 - ETA: 4s - los - ETA: 3s -
# Epoch 63/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.3582 - val_loss: 0.6632
# Epoch 64/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3185 - val_loss: 0.6998
# Epoch 65/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3243 - val_loss: 3.5874 - loss:
# Epoch 66/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.3468 - val_loss: 1.3246TA: 5 - ETA: 3s - loss: 0.33 - ETA: 3s - loss: 0.335 - ETA: 3s -
# Epoch 67/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.3178 - val_loss: 1.9620 loss
# Epoch 68/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3769 - val_loss: 0.5994- ETA: 1
# Epoch 69/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3713 - val_loss: 1.48864s - los - ETA: 3s - loss: - ETA: 0s - loss: 0.
# Epoch 70/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3548 - val_loss: 1.6684
# Epoch 71/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3738 - val_loss: 1.3028
# Epoch 72/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3144 - val_loss: 0.4287ss: 0.351 - ETA: 4s - loss: 0. - ETA: 3 - ETA: 2s - lo - ETA: 1s - loss: 0 - ETA: 0s - loss: 0.3 - ETA: 0s - los
# Epoch 73/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3007 - val_loss: 4.9035: 0s - loss: 0.3 - ETA: 0s - loss: 0.300
# Epoch 74/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3358 - val_loss: 11.1119 loss: 0.38 - ETA: 4s - loss: 0.3 - ETA:  - ETA: 2s - ETA: 1s
# Epoch 75/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3393 - val_loss: 31.9826
# Epoch 76/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3085 - val_loss: 3.0147 0.327 - ETA: 3s - loss: 0.326 - ETA:  - ETA: 2s - los - ETA: 1s - loss: 0. - ETA: 1s - lo - ETA: 0s - loss: 0.30
# Epoch 77/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2936 - val_loss: 0.23092s - loss:  - ETA: 1s - loss: 0.291 - ETA: 1s - - ETA: 0s - loss
# Epoch 78/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3171 - val_loss: 0.3666- loss: 0. - ETA: 1s -
# Epoch 79/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2976 - val_loss: 42.0047loss:
# Epoch 80/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.5537 - val_loss: 1.2183
# Epoch 81/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3281 - val_loss: 0.2847loss: 0.34 - ETA: 4s - loss: - ETA: 3s - loss: 0.33 - ETA: 3s - loss: - ETA: 2s - ETA: 1s - loss: 0. - ETA: 0s - loss: 0. - ETA: 0s - loss: 0. - ETA: 0s - loss: 0.3
# Epoch 82/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2964 - val_loss: 0.2367
# Epoch 83/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2787 - val_loss: 0.3454
# Epoch 84/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.3583 - val_loss: 0.4173
# Epoch 85/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3599 - val_loss: 9.7617o - ETA: 2s - loss: 0. - ETA: 2s - lo - ETA: 1s  - ETA: 0s - loss: 0
# Epoch 86/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3308 - val_loss: 2.7263s: 0.321 - ETA: 3s - loss: 0.320 - ETA - ETA: 2s - loss: 0. - ETA: 1s - - ETA: 0s - loss:
# Epoch 87/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3068 - val_loss: 0.7145- ETA: 3s - loss: 0.3 - ETA: 0s - loss: 0 - ETA: 0s - loss: 0.30
# Epoch 88/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2871 - val_loss: 0.31185s - loss: - ETA: 4s - l - ETA: 3s - loss: 0.281 - ETA: 3s - los - ETA: 2s - lo - ETA: 1s - loss: 0. - ETA: 1s - ETA: 0s - loss: 0.2
# Epoch 89/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3485 - val_loss: 0.8668TA: 5s  - E - ETA: 2s - loss: 0 - ETA: 1s - loss: 0.35 - ETA: 1s - loss: - ETA: 0s - lo
# Epoch 90/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3027 - val_loss: 0.7934 - loss:  - ETA: 1s - l - ETA: 0s - los
# Epoch 91/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2790 - val_loss: 0.4077ETA: 1s -
# Epoch 92/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2774 - val_loss: 0.4487loss: 0 - ETA: 0s - los
# Epoch 93/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3098 - val_loss: 0.29690s - loss
# Epoch 94/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3641 - val_loss: 0.3068
# Epoch 95/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2714 - val_loss: 0.6854 0s - loss: 0. - ETA: 0s - loss: 0.
# Epoch 96/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3154 - val_loss: 0.3214
# Epoch 97/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2807 - val_loss: 0.4119: 3s - lo - ETA: 2s - loss: 0.2 - ETA: 2s - loss: 0 - ETA: 2s - loss:  - ETA: 1s - loss: 0 - ETA: 1s - - ETA: 0s - loss: 0.280
# Epoch 98/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2719 - val_loss: 0.3146 4s - loss: 0.2
# Epoch 99/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2509 - val_loss: 0.2605TA: 4s - loss: 0. - ETA: 4s - loss:  - ETA: 3 - ETA: 2s - loss: 0 - ETA: 1s - loss: 0.24 - ETA: 1s - los - ETA: 0s - loss: 0. - ETA: 0s - loss:
# Epoch 100/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2636 - val_loss: 0.2758
# Epoch 101/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2817 - val_loss: 0.3408 ETA: 0s - loss: 0.2
# Epoch 102/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3496 - val_loss: 0.4229
# Epoch 103/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3530 - val_loss: 0.3863
# Epoch 104/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.4000 - val_loss: 0.3351: 0 - ETA: 3s - loss: 0. - ETA: 3s  - ETA: 1s - loss:  - ETA: 1s - l - ETA: 0s - loss: 0
# Epoch 105/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2536 - val_loss: 0.3676ETA: 5s - lo
# Epoch 106/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2734 - val_loss: 0.3446
# Epoch 107/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2789 - val_loss: 0.2929 - loss: - ETA: 2s - loss: - ETA: 1s - loss: - ETA: 1s -
# Epoch 108/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2345 - val_loss: 0.3819 ETA: 0s - loss: 0.23 - ETA: 0s - loss: 0.
# Epoch 109/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2680 - val_loss: 1.0342s - loss: 0.
# Epoch 110/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3354 - val_loss: 0.4471s: - ETA: 0s - loss: 0. - ETA: 0s - loss: 0.33
# Epoch 111/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.3300 - val_loss: 1.9573 5s - loss: 0.450 - ETA: 5s - loss: 0.4 - ETA: 4s - loss: 0 - ETA: 4s - loss: 0. - ETA: - ETA:  - ETA: 0s - l
# Epoch 112/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.2886 - val_loss: 0.5991.301 - ET - ETA: 0s - l
# Epoch 113/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.2838 - val_loss: 0.5914s: 0 - ETA: 0s - loss: 0.28 - ETA: 0s - loss: 0.283
# Epoch 114/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.2317 - val_loss: 0.2219: 2s - loss: 0.23 - E - ETA: 0s - loss: 0.23 - ETA: 0s - loss:
# Epoch 115/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.2721 - val_loss: 0.3594 2s - loss: 0.28 -
# Epoch 116/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.2678 - val_loss: 0.2790 ETA - ETA: 1s
# Epoch 117/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.2790 - val_loss: 0.3482
# Epoch 118/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.2499 - val_loss: 0.2366ETA: 0s - loss: 0.2
# Epoch 119/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.2394 - val_loss: 0.3390
# Epoch 120/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.2688 - val_loss: 0.2015
# Epoch 121/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.2747 - val_loss: 0.2777
# Epoch 122/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.3437 - val_loss: 0.3342
# Epoch 123/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.3384 - val_loss: 0.27594s - loss: 0. - ETA: 3s - loss: - ETA: 3s - l - ETA: 1s - loss:  - ETA: 1
# Epoch 124/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.2108 - val_loss: 0.2620ETA: 5s - l
# Epoch 125/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.2417 - val_loss: 0.2827   - ETA: 1s
# Epoch 126/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.2479 - val_loss: 0.4450
# Epoch 127/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.2196 - val_loss: 0.2944ETA: 2s - ETA: 0s - l
# Epoch 128/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.3728 - val_loss: 0.3518ETA: 3s - loss: 0 - ETA: 2s - l - ETA: 1s - loss: 0 - ETA: 1s -
# Epoch 129/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2732 - val_loss: 0.2340s - ETA: 1s - loss: 0. - ETA: 0s - los
# Epoch 130/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2964 - val_loss: 0.2822TA - ETA: 3s - loss: 0. - ETA: 3s - l - ETA: 2s - l - ETA: 1s - los - ETA: 0s - loss: 0.
# Epoch 131/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2672 - val_loss: 0.2395: 3s - loss: - ETA: 2s - los
# Epoch 132/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2273 - val_loss: 0.5594- loss:  - ETA: 0s - loss: 0.227
# Epoch 133/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.5537 - val_loss: 4.5268A: 4s - loss: 0 - ETA: - ETA: 2s - loss: 0 - ETA: 2s - lo - ETA: 1s - los - ETA: 0s - loss: 0
# Epoch 134/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.4213 - val_loss: 0.8916 - E - ETA: 0s - loss
# Epoch 135/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3188 - val_loss: 0.2464- ETA: 4s - loss: 0 - ETA: 4s - loss: 0. - ETA: 3s - loss: 0. - ETA: 3s - ETA: 2s - los - ETA: 1s - loss: 0.326 - ETA: 1s - loss - ETA: 0s - loss: 0 - ETA: 0s - loss: 0.3
# Epoch 136/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2731 - val_loss: 0.2714: 4 - ETA - ETA: 1
# Epoch 137/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2017 - val_loss: 0.3594.19 - ETA: 2s - loss: 0.1 - ETA: 1s - loss: 0. - ETA:
# Epoch 138/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2566 - val_loss: 0.3598: 2s - loss: 0.259 - ETA: 2s - los - ETA: 1
# Epoch 139/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2457 - val_loss: 0.2057TA: 5s - lo - ETA: 4s - loss: 0.223 - ETA: 4s - loss - ET - ETA:
# Epoch 140/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2256 - val_loss: 0.2928ETA: 2s - loss:  - E
# Epoch 141/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2357 - val_loss: 0.1998- ETA: 5s - los - ETA: 4s - loss: 0.238 - ETA: 4s - lo - ETA: 3s - loss: 0. - ETA: 3s - loss: 0. - ETA: 2s - loss: 0 - ETA - ETA: 0s - loss: 0. - ETA: 0s - loss:
# Epoch 142/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2209 - val_loss: 0.2655
# Epoch 143/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2190 - val_loss: 0.27630 - ETA: 3s - lo - ETA: 2s - loss: - ETA: 1s - loss:  - ETA: 1s - loss: 0. - ETA: 0s - loss: 0.217 - ETA: 0s - loss
# Epoch 144/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2576 - val_loss: 0.2353A: 3s - ETA: 1s - lo - ETA: 0s - los
# Epoch 145/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2496 - val_loss: 0.2598oss: 0.247 - ETA: 1s - lo - ETA: 1s - loss: 0.2 - ETA: 0s - loss:  - ETA: 0s - loss: 0.2
# Epoch 146/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2208 - val_loss: 0.2372A: 0s - loss: 0.2
# Epoch 147/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2331 - val_loss: 1.4990- ETA: 1s - l - ETA: 0s - loss:
# Epoch 148/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2534 - val_loss: 1.2478
# Epoch 149/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2635 - val_loss: 0.2251A: 3s - los - ETA: 2s - los -
# Epoch 150/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2281 - val_loss: 0.3794- ETA: 3s - loss: 0 - ETA: 2s - loss: 0.2 - ETA: 2s - loss: 0.2 - ETA: 2s - - ETA: 1s
# Epoch 151/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2614 - val_loss: 0.3605ETA: 0s - loss: 0.263 - ETA: 0s - loss:
# Epoch 152/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2155 - val_loss: 1.5884A: 2s -  - ETA: 0s -
# Epoch 153/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2304 - val_loss: 0.7122 4s - loss:
# Epoch 154/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2481 - val_loss: 0.6212 5s - loss: 0 - ETA: 2 - ETA: 0s - loss: - ETA: 0s - loss: 0
# Epoch 155/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2422 - val_loss: 1.7467ETA: 5s - loss: 0. - ETA:  - ETA: 3s - loss: 0.22 - ETA: 3s - los - ETA: 2s - los - ETA: 1s - los - ETA: 0s - loss: 0.242 - ETA: 0s - loss: 0 - ETA: 0s - loss: 0.242 - ETA: 0s - loss: 0.
# Epoch 156/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1964 - val_loss: 0.2182
# Epoch 157/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2349 - val_loss: 15.0000ETA: 3s - loss: 0 - ETA: 3s - loss: 0.2 - ETA: 3s - - E - ETA: 0s - loss: 0.234
# Epoch 158/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.3015 - val_loss: 0.2777: 3s - loss: 0.3 - ETA: 3s - loss: 0 - ETA: 2s - loss: 0 - ETA: 2s - loss: 0.311 - ET - ETA: 0s - loss:
# Epoch 159/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2429 - val_loss: 40.1665 ET - ETA: 2s - l - ETA: 1s - loss: 0 - ETA: 0s - lo
# Epoch 160/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2294 - val_loss: 8.6965- ETA: 4s - loss: 0.221 - ETA: 4s - loss: 0.2 - ETA: 3s - loss - ETA: 3s - loss: 0.2 - ETA: 2s - loss: - ETA: 2s - loss: 0 -
# Epoch 161/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1993 - val_loss: 156.8029 0s - loss: 0 - ETA: 0s - loss:
# Epoch 162/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2510 - val_loss: 437.9740A: 1s - loss: - ETA: 1s - loss:  - ETA: 0s - loss: 0.249 - ETA: 0s - loss: 0.2 - ETA: 0s - loss:
# Epoch 163/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2310 - val_loss: 62.0928A:  - ETA: 1s - loss: 0. - ETA: 0s - loss: 0.234 - ETA: 0s - l
# Epoch 164/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2072 - val_loss: 17.5326ETA: 2s - ETA:
# Epoch 165/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2444 - val_loss: 0.3320
# Epoch 166/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1985 - val_loss: 0.3092
# Epoch 167/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2219 - val_loss: 0.3614A: 1s - lo - ETA: 0s - loss: 0.2
# Epoch 168/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2113 - val_loss: 0.3447 ETA: 0s - loss: 0
# Epoch 169/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2089 - val_loss: 8.4251TA: 4s - los - ETA: 4s - - ETA: 0s - loss: 0 - ETA: 0s - loss: 0.2
# Epoch 170/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1776 - val_loss: 0.4333A: 1s - lo - ETA: 0s - loss:
# Epoch 171/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1983 - val_loss: 0.24780  - ETA: 0s - loss
# Epoch 172/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.2071 - val_loss: 8.611811 - ETA: 3s - loss:  - ETA: 2s - loss: 0. - ETA: 2s - loss: 0.211 - ETA: - ETA: 0s - loss
# Epoch 173/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1802 - val_loss: 18.7881- loss:
# Epoch 174/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1775 - val_loss: 0.5179oss  - ETA: 1s - lo - ETA: 0s - loss:
# Epoch 175/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1911 - val_loss: 0.3776
# Epoch 176/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2096 - val_loss: 0.5913TA: 5 - ETA: 4s - loss:  - ETA: 3s - loss: 0.2 - ETA: 3s - l - ETA: 2s -  - ETA: 1s
# Epoch 177/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2235 - val_loss: 0.3289s - l - ETA: 0s - loss:
# Epoch 178/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1939 - val_loss: 0.3363 - ETA: 1s
# Epoch 179/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2050 - val_loss: 0.2946
# Epoch 180/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1993 - val_loss: 0.2923TA: 4s - loss: 0 - ETA: 3s - ETA: - ETA: 0s - los
# Epoch 181/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2310 - val_loss: 0.3849 ETA: 5s - los - ETA: 5s  - - ETA: 1s - loss:  - ETA: 1s - los - ETA: 0s - loss: 0
# Epoch 182/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2227 - val_loss: 0.4802TA: 0s - l
# Epoch 183/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2089 - val_loss: 1.4201ETA: 3s  - ETA: 1s  - ETA: 0s - loss:
# Epoch 184/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2147 - val_loss: 7.0535os - ETA: 1s - loss: 0 - ETA: 0s - loss: 0.210 - ETA: 0s - loss: 0.2 - ETA: 0s - loss:  - ETA: 0s - loss: 0.21
# Epoch 185/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.2103 - val_loss: 0.6007ETA: 0s - loss:  - ETA: 0s - loss: 0.210
# Epoch 186/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.1856 - val_loss: 0.2570oss: 0. - ETA: 0s - loss: 0 - ETA: 0s - loss:
# Epoch 187/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.1779 - val_loss: 0.4542A - ETA: 3s
# Epoch 188/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.2047 - val_loss: 0.2534
# Epoch 189/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.1792 - val_loss: 1.4690 - loss:  - ETA: 4 - ETA - ETA:
# Epoch 190/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.1895 - val_loss: 1.0654: 5s - ETA: 3s - loss: 0 - ETA: 3s - los - ETA: 2s - - ETA: 1s -
# Epoch 191/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2115 - val_loss: 0.5381 ETA: 0s - loss: 0.211
# Epoch 192/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.1786 - val_loss: 24.7624- loss: 0 - ETA: 0s - loss: 0. - ETA: 0s - loss: 0.
# Epoch 193/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2382 - val_loss: 0.3251s:  - ETA: 3s - loss:  - ET - ETA: 0s - loss: 0.24 - ETA: 0s - loss:
# Epoch 194/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.1971 - val_loss: 0.3141s: 0 - ETA: 3s - loss: 0.1 - ETA - E
# Epoch 195/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.2750 - val_loss: 89.3661- ETA: 1s - loss:  - ETA: 0s - loss: 0.276 - ETA: 0s - los
# Epoch 196/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.1969 - val_loss: 2.9069A: 0s - loss - ETA: 0s - loss: 0.19
# Epoch 197/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.1867 - val_loss: 0.4562ETA: 5s - loss: 0. - ETA - ETA: 3s - loss:  - ETA: 2s - loss: 0. - ETA: 2s - loss: 0. - ET
# Epoch 198/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.1567 - val_loss: 0.2358oss: 0.146 - ETA: 4s - ETA: 2s - loss: 0 - ETA: 2s - los - ETA: 1
# Epoch 199/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.1571 - val_loss: 0.2095
# Epoch 200/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.1784 - val_loss: 0.20860s - los

# %%
Save_history = Model_history.history
Save_history = pd.DataFrame(Save_history)
writer = pd.ExcelWriter('C:/Users/Administrator/Desktop/surface/实验结果存放/PointNet-辅助信息版.xlsx')  #关键2，创建名称为hhh的excel表格
Save_history.to_excel(writer,'page_1',float_format='%.5f')  #关键3，float_format 控制精度，将data_df写到hhh表格的第一页中。若多个文件，可以在page_2中写入
writer.save()

# %%
############Test性能测试###################
def identification(predicted_gradient,real_gradient,threshold):
    AC13=[0,6,4,3.5,5.5,7.5,10.5,16,23.5,18.5,5,0]#级配
    AC16=[0,5.4,2.4,2.4,3.7,4.1,7.8,5.5,26.3,20.1,16.6,5.7]#级配 
    SMA13=[0,10.7,2.1,1.4,1.1,1.2,2.9,9.4,30.3,31.5,8.2,1.2]#级配
    UT5=[0,6.7,2,2.5,5,20,13.4,48.8,1.5,0.1,0,0]#级配
    OGFC10=[0,4,1.5,2,2,2.5,4,44,35,5,0,0]#级配
    
    R_AC13=np.average(np.abs(real_gradient-AC13))
    R_AC16=np.average(np.abs(real_gradient-AC16))
    R_SMA13=np.average(np.abs(real_gradient-SMA13))
    R_UT5=np.average(np.abs(real_gradient-UT5))
    R_OGFC10=np.average(np.abs(real_gradient-OGFC10))
    Real_result =np.argmin(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))
    """
    if np.average(np.abs(real_gradient-AC13))==0:
        Real_result=0
    elif np.average(np.abs(real_gradient-AC16))==0:
        Real_result=1
    elif np.average(np.abs(real_gradient-SMA13))==0:
        Real_result=2
    elif np.average(np.abs(real_gradient-UT5))==0:
        Real_result=3
    elif np.average(np.abs(real_gradient-OGFC10))==0:
        Real_result=4
    """
    R_AC13=np.average(np.abs(predicted_gradient-AC13))
    R_AC16=np.average(np.abs(predicted_gradient-AC16))
    R_SMA13=np.average(np.abs(predicted_gradient-SMA13))
    R_UT5=np.average(np.abs(predicted_gradient-UT5))
    R_OGFC10=np.average(np.abs(predicted_gradient-OGFC10))
    
    Predicted_result =np.argmin(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))
    
    if np.min(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))>threshold:
        Predicted_result = 5
    
    return Real_result, Predicted_result

n_classes = 12
PointNet= get_model(n_classes)
PointNet.load_weights("PointNet-辅助信息版.h5")
PointNet.compile(optimizer=keras.optimizers.Adam(lr=1e-3), loss=tf.keras.losses.MAE)
PointNet.evaluate([Test_X1_Data,Test_X2_Data],Test_Y_Data)
Thr_list = [0.5,1,1.5,2,2.5,3]
for Thr in Thr_list:
    Real_result = []
    Predicted_result = []
    for i in range(len(Test_X1_Data)):
        R,P=identification(PointNet([np.array(Test_X1_Data[i])[np.newaxis,...],np.array(Test_X2_Data[i])[np.newaxis,...]]),Test_Y_Data[i],Thr)
        Real_result.append(R)
        Predicted_result.append(P)
    #######绘制混淆矩阵################
    C = confusion_matrix(Real_result, Predicted_result, labels=[0,1,2,3,4,5]) 
    plt.matshow(C, cmap=plt.cm.Purples) # 根据最下面的图按自己需求更改颜色
    plt.colorbar()
    for i in range(len(C)):
        for j in range(len(C)):
            plt.annotate(C[j, i], xy=(i, j), horizontalalignment='center', verticalalignment='center')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.xticks(range(0,6), labels=['AC13','AC16','SMA13','UT5','OGFC10','Other'], rotation=20) # 将x轴或y轴坐标，刻度 替换为文字/字符
    plt.yticks(range(0,6), labels=['AC13','AC16','SMA13','UT5','OGFC10','Other'])
    plt.savefig('C:/Users/Administrator/Desktop/surface/实验结果存放/PointNet-辅助信息版'+ str(Thr) + '.png',dpi=600)#保存图片
    plt.show()
# Out:
# 7/7 [==============================] - 1s 44ms/step - loss: 0.2023
