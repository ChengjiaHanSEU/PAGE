# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
import numpy as np
import math
import sys
import os
from tensorflow.python.client import device_lib
import matplotlib.pyplot as plt
from plyfile import *
from mpl_toolkits.mplot3d import Axes3D
import open3d as o3d 
import numpy as np
import scipy.stats
import random
import pandas as pd
from sklearn.metrics import confusion_matrix
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
#点云文件导入
##############导入点云数据#################
pcd_AC13_1 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC13-1.ply")
pcd_AC13_2 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC13-2.ply")
pcd_AC16_3 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC16-3.ply")
pcd_AC16_4 = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/AC16-4.ply")
pcd_UT5_1  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-1.ply")
pcd_UT5_2  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-2.ply")
pcd_UT5_3  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-3.ply")
pcd_UT5_4  = o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/UT5-4.ply")
pcd_SMA13_1= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/SMA13-1.ply")
pcd_SMA13_2= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/SMA13-2.ply")
pcd_OGFC10_1= o3d.io.read_point_cloud("C:/Users/Administrator/Desktop/surface/OGFC10-1.ply")
#############点云标准化####################
def standard_pointcloud(point_cloud):
    Point_standard=[]
    Point=np.asarray(point_cloud.points)    
    x=np.array(Point[:,0])[...,np.newaxis]
    y=np.array(Point[:,1])[...,np.newaxis]
    z=np.array(Point[:,2])[...,np.newaxis]
    Point_standard=np.concatenate((x-np.min(x),y-np.min(y),z-np.min(z)),axis=-1)
    return Point_standard

AC13_1=standard_pointcloud(pcd_AC13_1)
AC13_2=standard_pointcloud(pcd_AC13_2)
AC16_3=standard_pointcloud(pcd_AC16_3)
AC16_4=standard_pointcloud(pcd_AC16_4)
UT5_1=standard_pointcloud(pcd_UT5_1)
UT5_2=standard_pointcloud(pcd_UT5_2)
UT5_3=standard_pointcloud(pcd_UT5_3)
UT5_4=standard_pointcloud(pcd_UT5_4)
SMA13_1= standard_pointcloud(pcd_SMA13_1)
SMA13_2= standard_pointcloud(pcd_SMA13_2)
OGFC10_1 =  standard_pointcloud(pcd_OGFC10_1)

point_cloud_array_group = []
point_cloud_array_group.append(AC13_1)
point_cloud_array_group.append(AC13_2)
point_cloud_array_group.append(AC16_3)
point_cloud_array_group.append(AC16_4)
point_cloud_array_group.append(UT5_1)
point_cloud_array_group.append(UT5_2)
point_cloud_array_group.append(UT5_3)
point_cloud_array_group.append(UT5_4)
point_cloud_array_group.append(SMA13_1)
point_cloud_array_group.append(SMA13_2)
point_cloud_array_group.append(OGFC10_1)
#############点云标准化####################
def standard_pointcloud(point_cloud):
    Point_standard=[]  
    x=np.array(point_cloud[:,0])[...,np.newaxis]
    y=np.array(point_cloud[:,1])[...,np.newaxis]
    z=np.array(point_cloud[:,2])[...,np.newaxis]
    Point_standard=np.concatenate((x-np.min(x),y-np.min(y),z-np.min(z)),axis=-1)
    return Point_standard
######################按照计算的H_final进行窗口滑动切分#########################
H_final=51
AC13=[0,6,4,3.5,5.5,7.5,10.5,16,23.5,18.5,5,0]#级配
AC16=[0,5.4,2.4,2.4,3.7,4.1,7.8,5.5,26.3,20.1,16.6,5.7]#级配 
SMA13=[0,10.7,2.1,1.4,1.1,1.2,2.9,9.4,30.3,31.5,8.2,1.2]#级配
UT5=[0,6.7,2,2.5,5,20,13.4,48.8,1.5,0.1,0,0]#级配
OGFC10=[0,4,1.5,2,2,2.5,4,44,35,5,0,0]#级配
def split_slide(point_cloud_array_origion,H_new=H_final, intervial =[5,5]):
    L=int(np.max(point_cloud_array_origion[:,0]))
    W=int(np.max(point_cloud_array_origion[:,1]))
    Point_cloud_small = []
    L_intervial = intervial[0]
    W_intervial = intervial[1]
    for i in range (0,L-H_new,L_intervial):
        for j in range (0,W-H_new,W_intervial):
            temp_point_cloud = point_cloud_array_origion[np.where((point_cloud_array_origion[:,1]>i)&
                                                                  (point_cloud_array_origion[:,1]<(H_new+i))&
                                                                  (point_cloud_array_origion[:,0]>j)&
                                                                  (point_cloud_array_origion[:,0]<(H_new+j)))]
            temp_point_cloud = standard_pointcloud(temp_point_cloud)
            Point_cloud_small.append(temp_point_cloud)
    return Point_cloud_small
####################原始图像拆分子点云集########################################
PointCloud_new =[]
#制作Ground truth
Y_Data=np.zeros((1,12))
for i in range(11):
    temp=split_slide(point_cloud_array_group[i])
    #print(len(temp))
    PointCloud_new=np.concatenate((PointCloud_new,temp),axis=0)
    if (i==0) or (i==1):
        temp2 = np.full((len(temp),12),AC13)
    elif (i==2) or (i==3):
        temp2 = np.full((len(temp),12),AC16)
    elif (i==4) or (i==5) or (i==6) or (i==7):
        temp2 = np.full((len(temp),12),UT5)
    elif (i==8) or (i==9):
        temp2 = np.full((len(temp),12),SMA13)
    elif (i==10):
        temp2 = np.full((len(temp),12),OGFC10) 
    #print(temp2.shape)
    Y_Data = np.concatenate((Y_Data,temp2),axis=0)
    #print(np.array(Y_Data).shape)
Y_Data = np.delete(Y_Data, 1, 0)#把第一行0删掉
print(Y_Data.shape)
#print(len(PointCloud_new))
#计算最小子点云点数
num_min=PointCloud_new[0].shape[0]
for i in range(len(PointCloud_new)):
    num_point = PointCloud_new[i].shape[0]
    if num_min>num_point:
        num_min = num_point
#print(num_min)
#根据最小点云数进行降采样，根据设置的点数降采样
def pointCloud_downsampling(Point_cloud_array, num_pointCloud=30000):
    # estimate radius for rolling ball
    pcd=o3d.geometry.PointCloud()
    pcd.points=o3d.utility.Vector3dVector(Point_cloud_array)
    pcd.estimate_normals()
    # estimate radius for rolling ball
    distances = pcd.compute_nearest_neighbor_distance()
    avg_dist = np.mean(distances)
    radius = 1.5 * avg_dist   
    mesh = o3d.geometry.TriangleMesh.create_from_point_cloud_ball_pivoting(pcd,o3d.utility.DoubleVector([radius, radius * 2]))
    pcd_new = o3d.geometry.TriangleMesh.sample_points_uniformly(mesh, number_of_points=num_pointCloud) # 采样点云
    #o3d.visualization.draw_geometries([pcd_new],width=1024, height=1024)
    New_Point_cloud_array = np.asarray(pcd_new.points)
    return New_Point_cloud_array

PointCloud_Standard =[]
for i in range(len(PointCloud_new)):
    PointCloud_Standard.append(pointCloud_downsampling(PointCloud_new[i],6000))
print(np.array(PointCloud_Standard).shape)
# Out:
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# (1579, 12)
# (1579, 6000, 3)

# %%
#### 数据集1579分，切分为1379训练 200测试#######################
arr = np.array(range(0, 1579, 1))
r = np.random.permutation(arr)
Train_X_Data = []
Train_Y_Data = []
for i in range(1379):
    Train_X_Data.append(PointCloud_Standard[r[i]])
    Train_Y_Data.append(Y_Data[r[i]])

Test_X_Data = []
Test_Y_Data = []
for i in range(1379,1579):
    Test_X_Data.append(PointCloud_Standard[r[i]])
    Test_Y_Data.append(Y_Data[r[i]])
    
Train_X_Data = np.array(Train_X_Data)
Train_Y_Data = np.array(Train_Y_Data)
Test_X_Data = np.array(Test_X_Data)
Test_Y_Data = np.array(Test_Y_Data)

print(Train_X_Data.shape)
print(Train_Y_Data.shape)
print(Test_X_Data.shape)
print(Test_Y_Data.shape)
# Out:
# (1379, 6000, 3)
# (1379, 12)
# (200, 6000, 3)
# (200, 12)

# %%
class CustomConvolution(keras.layers.Layer):
    def __init__(self, filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID', bn_momentum=0.99,
                 activation=None, apply_bn=False):
        super(CustomConvolution, self).__init__()
        self.filters = filters
        self.kernel_size = kernel_size
        self.strides = strides
        self.padding = padding
        self.bn_momentum = bn_momentum
        self.activation = activation
        self.convolution = keras.layers.Conv2D(filters, kernel_size, strides, padding)
        self.apply_bn = apply_bn
        if self.apply_bn:
            self.bn = keras.layers.BatchNormalization(momentum=bn_momentum)

    def call(self, inputs, training=None):
        x = self.convolution(inputs)
        if self.apply_bn:
            x = self.bn(x, training=training)
        if self.activation:
            x = self.activation(x)
        return x

    def get_config(self):
        config = super(CustomConvolution, self).get_config()
        config.update(
            {
                'filters': self.filters,
                'kernel_size': self.kernel_size,
                'strides': self.strides,
                'padding': self.padding,
                'bn_momentum': self.bn_momentum,
                'activation': self.activation,
                'apply_bn': self.apply_bn
            }
        )
    @classmethod
    def from_config(cls, config):
        return cls(**config)

class CustomDense(keras.layers.Layer):
    def __init__(self, units=256, activation=tf.nn.relu, bn_momentum=0.99, apply_bn=False):
        super(CustomDense, self).__init__()
        self.filters = units
        self.bn_momentum = bn_momentum
        self.activation = activation
        self.dense = keras.layers.Dense(units)
        self.apply_bn = apply_bn
        if self.apply_bn:
            self.bn = keras.layers.BatchNormalization(momentum=bn_momentum)

    def call(self, inputs, training=None):
        x = self.dense(inputs)
        if self.apply_bn:
            x = self.bn(x, training=training)
        if self.activation:
            x = self.activation(x)
        return x

    def get_config(self):
        config = super(CustomDense, self).get_config()
        config.update(
            {
                'units': self.units,
                'activation': self.activation,
                'bn_momentum': self.bn_momentum,
                'apply_bn': self.apply_bn
            }
        )

    @classmethod
    def from_config(cls, config):
        return cls(**config)

class input_TransformNet(keras.layers.Layer):
    def __init__(self, add_regularization=False, bn_momentum=0.99, name=None, **kwargs):
        super(input_TransformNet, self).__init__(name=name, **kwargs)
        self.add_regularization = add_regularization
        self.bn_momentum = bn_momentum
        self.conv0 = CustomConvolution(filters=64, kernel_size=(1, 3), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)
        self.conv1 = CustomConvolution(filters=128, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.conv2 = CustomConvolution(filters=1024, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense0 = CustomDense(units=512, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)

    def build(self, input_shape):
        self.K = input_shape[2]
        self.w = self.add_weight(name='w', shape=[256, self.K ** 2], initializer=tf.zeros_initializer, dtype=tf.float32)
        self.b = self.add_weight(name='b', shape=(self.K, self.K), initializer=tf.zeros_initializer, dtype=tf.float32)
        I = tf.constant(np.eye(self.K), dtype=tf.float32)
        self.b = tf.math.add(self.b, I)

    def call(self, inputs, training=None):
        x = inputs  # BxNx3
        x = tf.expand_dims(x, axis=-1)  # BxNx3x1
        x = self.conv0(x, training=training)  # BxNx1x64
        x = self.conv1(x, training=training)  # BxNx1x128
        x = self.conv2(x, training=training)  # BxNx1x1024
        x = tf.squeeze(x, axis=2)  # BxNx1024
        x = tf.reduce_max(x, axis=1)  # Bx1024sss
        x = self.dense0(x, training=training)  # Bx512
        x = self.dense1(x, training=training)  # Bx256

        x = tf.expand_dims(x, axis=1)  # Bx1x256
        x = tf.matmul(x, self.w)  # Bx1xK**2
        x = tf.squeeze(x, axis=1)  # BxK**2
        x = tf.reshape(x, (-1, self.K, self.K))  # BxKxK
        x += self.b

        if self.add_regularization:
            eye = tf.constant(np.eye(self.K), dtype=tf.float32)
            x_transpose = tf.transpose(x, perm=[0, 2, 1])
            x_xt = tf.matmul(x, x_transpose)
            reg = tf.nn.l2_loss(eye - x_xt)
            self.add_loss(1e-3 * reg)

        return tf.matmul(inputs, x)

    def get_config(self):
        config = super(TransformNet, self).get_config()
        config.update(
            {
                'add_regularization': self.add_regularization,
                'bn_momentum': self.bn_momentum,
            }
        )

    @classmethod
    def from_config(cls, config):
        return cls(**config)

class feature_TransformNet(keras.layers.Layer):
    def __init__(self, add_regularization=False, bn_momentum=0.99, name=None, **kwargs):
        super(feature_TransformNet, self).__init__(name=name, **kwargs)
        self.add_regularization = add_regularization
        self.bn_momentum = bn_momentum
        self.conv0 = CustomConvolution(filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)
        self.conv1 = CustomConvolution(filters=128, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.conv2 = CustomConvolution(filters=1024, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense0 = CustomDense(units=512, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)
        self.dense1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=self.bn_momentum,apply_bn=True)

    def build(self, input_shape):
        self.K = input_shape[-1]
        self.w = self.add_weight(name='w', shape=[256, self.K ** 2], initializer=tf.zeros_initializer, dtype=tf.float32)
        self.b = self.add_weight(name='b', shape=(self.K, self.K), initializer=tf.zeros_initializer, dtype=tf.float32)
        I = tf.constant(np.eye(self.K), dtype=tf.float32)
        self.b = tf.math.add(self.b, I)

    def call(self, inputs, training=None):
        x = inputs  # BxNx1x64
        x = self.conv0(x, training=training)  # BxNx1x64
        x = self.conv1(x, training=training)  # BxNx1x128
        x = self.conv2(x, training=training)  # BxNx1x1024
        x = tf.squeeze(x, axis=2)  # BxNx1024
        x = tf.reduce_max(x, axis=1)  # Bx1024sss
        x = self.dense0(x, training=training)  # Bx512
        x = self.dense1(x, training=training)  # Bx256

        x = tf.expand_dims(x, axis=1)  # Bx1x256
        x = tf.matmul(x, self.w)  # Bx1xK**2
        x = tf.squeeze(x, axis=1)  # BxK**2
        x = tf.reshape(x, (-1, self.K, self.K))  # BxKxK
        x += self.b

        if self.add_regularization:
            eye = tf.constant(np.eye(self.K), dtype=tf.float32)
            x_transpose = tf.transpose(x, perm=[0, 2, 1])
            x_xt = tf.matmul(x, x_transpose)
            reg = tf.nn.l2_loss(eye - x_xt)
            self.add_loss(1e-3 * reg)

        return tf.matmul(tf.squeeze(inputs, axis=2), x) #BxNxK 把第3轴去掉保持维度统一

    def get_config(self):
        config = super(TransformNet, self).get_config()
        config.update(
            {
                'add_regularization': self.add_regularization,
                'bn_momentum': self.bn_momentum,
            }
        )

    @classmethod
    def from_config(cls, config):
        return cls(**config)

def get_model(n_classes, bn_momentum=0.99):
    add_regularization = True
    # Initialize the input layer
    input_layer = keras.Input(shape=(None, 3),
                              name='input_points')  # MxNx3 where M is batch size,N is number of points and 3 for channels
    # Input transform layer
    input_transform = input_TransformNet(add_regularization=add_regularization, bn_momentum=bn_momentum,
                                   name='input_transformation')(input_layer)  # BxNx3 --> BxNx3
    input_transform = tf.expand_dims(input_transform, axis=-1)  # BxNx3 --> BxNx3x1

    shared_layer_1 = CustomConvolution(filters=64, kernel_size=(1, 3), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(input_transform)  # BxNx3x1 --> BxNx1x64
    shared_layer_2 = CustomConvolution(filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(shared_layer_1)  # BxNx1x64 --> BxNx1x64
    #shared_layer_2 = tf.squeeze(shared_layer_2, axis=2) # BxNx1x64 --> BxNx64

    feature_transform = feature_TransformNet(add_regularization=add_regularization, bn_momentum=bn_momentum,
                                             name='feature_transformation')(shared_layer_2)  # BxNx1x64--> BxNx64
    feature_transform = tf.expand_dims(feature_transform, axis=2)  # BxNx64 --> BxNx1x64

    shared_layer_3 = CustomConvolution(filters=64, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(feature_transform)  # BxNx1x64 --> BxNx1x64
    shared_layer_4 = CustomConvolution(filters=128, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(shared_layer_3)  # BxNx1x64 --> BxNx1x128
    shared_layer_5 = CustomConvolution(filters=1024, kernel_size=(1, 1), strides=(1, 1), padding='VALID',
                                       bn_momentum=bn_momentum, activation=tf.nn.relu,apply_bn=True)(shared_layer_4)  # BxNx1x128 --> BxNx1x1024

    shared_layer_5 = tf.squeeze(shared_layer_5, axis=2)  # BxNx1x1024 --> BxNx1024

    global_features = tf.reduce_max(shared_layer_5, axis=1)  # BxNx1024 --> Bx1024

    dense0 = CustomDense(units=512, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(global_features)
    #dense0 = keras.layers.Dropout(0.5)(dense0)
    dense1 = CustomDense(units=256, activation=tf.nn.relu, bn_momentum=bn_momentum,apply_bn=True)(dense0)
    #dense1 = keras.layers.Dropout(0.5)(dense1)
    dense1 = keras.layers.Flatten()(dense1)

    output_layer = keras.layers.Dense(units=n_classes, activation=tf.nn.relu)(dense1)#级配每档的分计筛余比例

    model = keras.Model(inputs=input_layer, outputs=output_layer)
    return model

# %%
################网络训练###########################
n_classes = 12
PointNet= get_model(n_classes)
PointNet.summary()
logdir = "./data/log"
lr = 1e-3
#PointNet.load_weights("PointNet.h5")
PointNet.compile(optimizer=keras.optimizers.Adam(lr), 
                 loss=tf.keras.losses.MAE)
Callback = keras.callbacks.ModelCheckpoint("PointNet-6000点版本.h5", 
                                           monitor='val_loss', 
                                           save_best_only=True, 
                                           save_weights_only=True)
Model_history=PointNet.fit(x=Train_X_Data,y=Train_Y_Data,batch_size=16,epochs = 200,validation_split=0.2,callbacks=Callback)
#PointNet.save_weights("PointNet.h5")
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_points (InputLayer)    [(None, None, 3)]         0
# _________________________________________________________________
# input_transformation (input_ (None, None, 3)           807040
# _________________________________________________________________
# tf.expand_dims_2 (TFOpLambda (None, None, 3, 1)        0
# _________________________________________________________________
# custom_convolution_14 (Custo (None, None, 1, 64)       512
# _________________________________________________________________
# custom_convolution_15 (Custo (None, None, 1, 64)       4416
# _________________________________________________________________
# feature_transformation (feat (None, None, 64)          1857216
# _________________________________________________________________
# tf.expand_dims_3 (TFOpLambda (None, None, 1, 64)       0
# _________________________________________________________________
# custom_convolution_19 (Custo (None, None, 1, 64)       4416
# _________________________________________________________________
# custom_convolution_20 (Custo (None, None, 1, 128)      8832
# _________________________________________________________________
# custom_convolution_21 (Custo (None, None, 1, 1024)     136192
# _________________________________________________________________
# tf.compat.v1.squeeze_1 (TFOp (None, None, 1024)        0
# _________________________________________________________________
# tf.math.reduce_max_1 (TFOpLa (None, 1024)              0
# _________________________________________________________________
# custom_dense_10 (CustomDense (None, 512)               526848
# _________________________________________________________________
# custom_dense_11 (CustomDense (None, 256)               132352
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 12)                3084
# =================================================================
# Total params: 3,480,908
# Trainable params: 3,468,748
# Non-trainable params: 12,160
# _________________________________________________________________
# Epoch 1/200
# 69/69 [==============================] - 9s 106ms/step - loss: 7.2301 - val_loss: 6.1977
# Epoch 2/200
# 69/69 [==============================] - 7s 100ms/step - loss: 4.6232 - val_loss: 7.8943
# Epoch 3/200
# 69/69 [==============================] - 7s 100ms/step - loss: 3.9128 - val_loss: 7.1294 ETA - ETA: 3
# Epoch 4/200
# 69/69 [==============================] - 7s 99ms/step - loss: 3.5603 - val_loss: 7.8036TA: 2s - loss: 3 -
# Epoch 5/200
# 69/69 [==============================] - 7s 99ms/step - loss: 3.1444 - val_loss: 5.4861
# Epoch 6/200
# 69/69 [==============================] - 7s 99ms/step - loss: 2.7873 - val_loss: 10.9875ETA: 3s - l - ETA: 2s - loss: 2.758 - ETA: 2s - lo - ETA: 1s - loss - ETA: 0s - loss: 2. - ETA: 0s - loss:
# Epoch 7/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.8855 - val_loss: 12.8420 1s - loss: - ETA: 0s - loss: 2.878 - ETA: 0s - loss: 2.
# Epoch 8/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.6350 - val_loss: 5.0721 loss: 2 - ETA: 2s - lo - ETA: 1s - loss: 2.630 - ETA: 1s -
# Epoch 9/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.6416 - val_loss: 3.7344ETA: 4s - loss: 2.76
# Epoch 10/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.1637 - val_loss: 32.4258: 0s - loss: 2.1
# Epoch 11/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.3336 - val_loss: 8.5870
# Epoch 12/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.4194 - val_loss: 4.9128 loss: 2. - ETA: 0s - loss:
# Epoch 13/200
# 69/69 [==============================] - 7s 99ms/step - loss: 2.6908 - val_loss: 3.5826
# Epoch 14/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.4710 - val_loss: 10.2886
# Epoch 15/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.2332 - val_loss: 6.2128 ETA: 5s - loss: 2. - ETA: 5s - loss: 2. - ETA: 4s - loss: 2.14 - ETA: 4s - loss: - ETA - ET - ETA: 0s - loss: 2.
# Epoch 16/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.1603 - val_loss: 14.6937- ETA: 2s - loss: - ETA: 1s - loss:  - ETA: 1s - loss - ETA: 0s - loss:
# Epoch 17/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.5241 - val_loss: 8.3890: 2s - loss: 2 - ETA: 2s - l - ETA:
# Epoch 18/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.8826 - val_loss: 7.7292 - ETA: 1s - - ETA: 0s - loss: 1.8
# Epoch 19/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.0492 - val_loss: 4.9839-  - ETA: 3
# Epoch 20/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.4260 - val_loss: 3.0437- loss: 2 - ETA: 3s - loss - ETA: 2s - loss: - ETA: 2s - loss: 2.509
# Epoch 21/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.0522 - val_loss: 3.5188 1s - loss - ETA: 0s - loss: 2
# Epoch 22/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.9497 - val_loss: 5.6236ETA: 0s - loss: 1.941 - ETA: 0s - loss:  - ETA: 0s - loss: 1.9
# Epoch 23/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.1753 - val_loss: 4.4242 - ETA: 0s - loss: 2.18
# Epoch 24/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.7516 - val_loss: 6.6661 ETA: 0s - loss: 1.7
# Epoch 25/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.5640 - val_loss: 2.0018
# Epoch 26/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.7416 - val_loss: 5.1795 ETA: 2s - loss: 1 - ETA: 1s - los - ETA: 1s -
# Epoch 27/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.4861 - val_loss: 7.4134ETA: 3s - loss:  - ETA: 2s - loss: 1 - ETA: 2s - ETA: 0s - lo
# Epoch 28/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.5982 - val_loss: 5.1845 loss: 1.59
# Epoch 29/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.4462 - val_loss: 14.3625
# Epoch 30/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.7853 - val_loss: 3.1097  - ETA: 1s - loss: 1. - ETA: 1s - loss: 1.786 - ETA: 1s -
# Epoch 31/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.8209 - val_loss: 4.4504TA: 0s - loss: 1.
# Epoch 32/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.7075 - val_loss: 5.0677
# Epoch 33/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.1485 - val_loss: 16.9361A: 3s - loss: 2. - ETA: 2s - loss: 2.19 - ETA: 2s - loss: 2.19 - ETA: 2s - loss: 2.1 - ETA: 2s - loss: 2. - E
# Epoch 34/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.1419 - val_loss: 7.6111
# Epoch 35/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.7423 - val_loss: 4.8216
# Epoch 36/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3374 - val_loss: 13.6490
# Epoch 37/200
# 69/69 [==============================] - 7s 100ms/step - loss: 5.4799 - val_loss: 4.2982: 5.496
# Epoch 38/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.9628 - val_loss: 3.0934
# Epoch 39/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.6823 - val_loss: 2.9407: 0s - loss:
# Epoch 40/200
# 69/69 [==============================] - 7s 100ms/step - loss: 2.1673 - val_loss: 3.0757: 2. - ETA: 1
# Epoch 41/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.9694 - val_loss: 2.6133
# Epoch 42/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.8036 - val_loss: 3.7310 ETA: 3s - -
# Epoch 43/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.4657 - val_loss: 2.3775
# Epoch 44/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.6682 - val_loss: 5.2763
# Epoch 45/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.5092 - val_loss: 5.3687s - loss - ETA
# Epoch 46/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.4861 - val_loss: 3.9490- ETA: 3s -  - ETA: 2s - loss - ETA: 1s - loss: 1. - ETA: 1s - loss: 1.4 - ETA: 0s - lo
# Epoch 47/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2497 - val_loss: 4.3696 - los - ETA: 3s - loss: 1.216 - ETA: -
# Epoch 48/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2539 - val_loss: 7.3859s - loss: 1 - ETA: 3s - los
# Epoch 49/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.4176 - val_loss: 4.06701.5 - ETA: 3s - l - ETA: 2s - loss:  - ETA: 2s - loss: 1.45 - ETA: 2s - - ETA: 0s - loss: 1.43 - ETA: 0s - loss
# Epoch 50/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.4889 - val_loss: 7.05664s - - ETA: 1s - l - ETA: 0s - loss: 1.
# Epoch 51/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.4417 - val_loss: 3.3580A: 0s - loss: 1.4
# Epoch 52/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.3512 - val_loss: 2.1020
# Epoch 53/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1899 - val_loss: 2.37151s - loss - ETA: 0s - loss
# Epoch 54/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.2539 - val_loss: 4.6229
# Epoch 55/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3531 - val_loss: 3.1210 ETA: 4s - ETA: 3s - loss: 1.266 - ETA: 3s - lo
# Epoch 56/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.5040 - val_loss: 5.1903:  - ETA: 1s - loss: 1 - ETA: 0s - l
# Epoch 57/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.6552 - val_loss: 2.8040A: 4s - loss: 1.8 -  - ETA: 2s -  - ETA: 1s
# Epoch 58/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3602 - val_loss: 4.4532  - ETA: 3s - loss: 1.30 - ETA: 1s -
# Epoch 59/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.2826 - val_loss: 3.5200.26 - ETA: 3s - l
# Epoch 60/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2127 - val_loss: 4.9553 ETA: 0s - lo
# Epoch 61/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2729 - val_loss: 6.6348ETA: 3s - loss: 1. - ETA: 0s - lo
# Epoch 62/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.6801 - val_loss: 2.6919s - loss: 1.91 - ETA: 5s - lo - ETA: 4s - loss: 1.8 - ETA: 3s - lo - ETA: 0s - loss
# Epoch 63/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3716 - val_loss: 1.8574 ETA: 5s - loss: 1.9 - ETA: 5s - loss - ET - ETA: 2s - loss: 1. - ETA: 2s - loss: 1.4 - ETA: 1s - loss: 1.4 - ETA:
# Epoch 64/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.3288 - val_loss: 3.0129
# Epoch 65/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3596 - val_loss: 3.8729A: 0s - loss: 1.
# Epoch 66/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3194 - val_loss: 2.5914 5s - loss: 1.4 - ETA: 5s - loss: 1. - - ETA: 2s - l - ETA: 1s - loss: 1.3 - ETA: 1
# Epoch 67/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.2462 - val_loss: 1.7893
# Epoch 68/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1345 - val_loss: 3.70881
# Epoch 69/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.5149 - val_loss: 3.1473
# Epoch 70/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.5245 - val_loss: 2.7622
# Epoch 71/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.1431 - val_loss: 2.9428- ETA: 2s - loss: 1 - E
# Epoch 72/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.4683 - val_loss: 2.5554loss: 1.48 - E - ETA: 0s - loss: 1
# Epoch 73/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0929 - val_loss: 3.7133: 1.161 -
# Epoch 74/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2406 - val_loss: 3.1867
# Epoch 75/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.3427 - val_loss: 3.3206
# Epoch 76/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.4839 - val_loss: 2.55394s - loss: 1.41 - ETA: 2s - ETA: 0s - l
# Epoch 77/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1950 - val_loss: 6.0707ETA: 5s - loss: 1.64 - ETA: 5s - loss - ETA: 4s -  - ETA: 3s - loss - ETA: 2s - l - E
# Epoch 78/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2235 - val_loss: 3.6133
# Epoch 79/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3122 - val_loss: 5.0438ETA: 5s - los - ETA: 4s  - ETA: 0s - loss: 1.33 - ETA: 0s - los
# Epoch 80/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8787 - val_loss: 2.0941A: 5s - lo - ETA: 4s - ETA: 0s - los - ETA: 0s - loss: 0.876
# Epoch 81/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1346 - val_loss: 2.4030 1. - ETA: 4s - loss: 1.29 - ETA: 3s - loss: 1.283 - ETA: 3s - loss: 1 - ETA: 3s - - ETA: 2s - loss: 1.185 -
# Epoch 82/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9129 - val_loss: 1.4538ETA: 5s - loss: 0 - ETA: 5s - loss: 0.66 - ETA: 5s - loss - ETA:  - ETA: 3s - - E
# Epoch 83/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1242 - val_loss: 1.6843
# Epoch 84/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.0338 - val_loss: 4.7361
# Epoch 85/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0215 - val_loss: 1.8296 4 - ETA: 3s - loss: 0 - ETA: 2s - loss:  - ETA: 2s - lo - ETA:
# Epoch 86/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1221 - val_loss: 4.6895ETA: 3s - loss: 1.060 - ETA: 3s - loss:  - ETA: - ETA: 1s - lo - ETA: 0s - loss: 1.
# Epoch 87/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1622 - val_loss: 4.6891: 4s - lo - ETA: 1s - los - ETA: 0s - loss
# Epoch 88/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3876 - val_loss: 3.2027TA:  - ETA: 0s - lo
# Epoch 89/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9857 - val_loss: 3.9808
# Epoch 90/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9180 - val_loss: 2.7354
# Epoch 91/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9275 - val_loss: 5.2542  - ETA: 0s - loss: 0.923 - ETA: 0s - loss:
# Epoch 92/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0405 - val_loss: 1.9232
# Epoch 93/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0641 - val_loss: 1.9369
# Epoch 94/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0786 - val_loss: 3.8109
# Epoch 95/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9806 - val_loss: 3.6139TA: 0s - loss: 0.9
# Epoch 96/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9626 - val_loss: 3.9279
# Epoch 97/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.3105 - val_loss: 3.8086s  -  - ETA: 1s -
# Epoch 98/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.6309 - val_loss: 3.4035 -
# Epoch 99/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7598 - val_loss: 1.7762
# Epoch 100/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8138 - val_loss: 2.3976
# Epoch 101/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9836 - val_loss: 1.8644
# Epoch 102/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2978 - val_loss: 3.3440 - loss: 1.344 - E - ETA: 0s - loss: 1.3
# Epoch 103/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1497 - val_loss: 1.1219ETA: 1s - loss: 1. - ETA: 0s - loss - ETA: 0s - loss: 1.15
# Epoch 104/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0304 - val_loss: 1.3328
# Epoch 105/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9202 - val_loss: 5.3506 ETA: 2s - loss: - ETA: 2s - loss: 0.91 -
# Epoch 106/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9641 - val_loss: 3.5972
# Epoch 107/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7411 - val_loss: 3.4796- ETA: 5s - loss: 0.4 - ETA: 5s - loss: 0.473 - ETA: 5s - loss: 0.4 - ETA: 5s - loss:
# Epoch 108/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.1126 - val_loss: 2.9573 ETA: 4s - - ETA: 1s
# Epoch 109/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9270 - val_loss: 2.8898
# Epoch 110/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.1352 - val_loss: 2.2445
# Epoch 111/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8378 - val_loss: 1.5343 - loss: 0 - ETA: 3s -
# Epoch 112/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0515 - val_loss: 5.6658 ETA: 4s - l - ETA: 3s - loss: 1. - ETA: 3s - loss: 1.154 - ETA: 3s - loss: 1.1 - ETA: 2s - loss
# Epoch 113/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.0174 - val_loss: 4.9728ETA: 5s - loss: 0.899 - ETA - ETA:  - ETA: 1s - loss: - ETA: 1s -
# Epoch 114/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2218 - val_loss: 2.6729
# Epoch 115/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.1029 - val_loss: 1.7417
# Epoch 116/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8543 - val_loss: 1.54435s - loss: 0.995 - ETA: 4s - los - ETA: 4s -  - ETA: 3s - loss: 0.932 - ETA: 2s - - ET
# Epoch 117/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.0338 - val_loss: 2.78612 - ETA: 1s
# Epoch 118/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9303 - val_loss: 1.5032ETA: 1s
# Epoch 119/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9356 - val_loss: 1.9905- ETA: 3s - loss: 1.076 - ETA: - ETA:  - ETA: 0s - loss: 0.
# Epoch 120/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.6517 - val_loss: 2.6303TA: 2s - los - ETA: 1s - loss: 0.6 - ETA: 1s -
# Epoch 121/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.7637 - val_loss: 2.0525
# Epoch 122/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9260 - val_loss: 2.3974: 2 - ETA: 1s - loss: 0. - ETA: 0s - los
# Epoch 123/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8077 - val_loss: 5.3718 - ETA: 3s - los - ETA: 2s - loss:  - ETA: 2s - ETA: 1s - loss:  - ETA: 0s - loss: 0.79 - ETA: 0s - loss: 0.
# Epoch 124/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8002 - val_loss: 5.0911A: 0s - l
# Epoch 125/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9225 - val_loss: 2.4379 0s - loss: 0.92
# Epoch 126/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0978 - val_loss: 2.5135
# Epoch 127/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.7960 - val_loss: 3.2193
# Epoch 128/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.1605 - val_loss: 2.2689: 5s - loss:  - ETA: 4s -  - ETA: 3s - loss: 1.110 - ETA: 3s - los  - ETA: 0s - los
# Epoch 129/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.9153 - val_loss: 2.4032 5s - loss: 0.913 - ETA: - ETA: 3s - loss: 0.931 - ETA: 3s - loss: 0.93 - ETA: 3s - loss: 0. - ETA: 2s - loss: 0.91 - ETA: 2s - loss: 0.913 - ETA: 2s - loss: 0. - ETA: 2s - l - ETA: 1s -
# Epoch 130/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8126 - val_loss: 3.4975
# Epoch 131/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9199 - val_loss: 4.0356s: 0. - ETA: 0s - l
# Epoch 132/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.9734 - val_loss: 1.6063ETA: 5s - loss: 0.8 - ETA: 2s - ETA: 1s - loss: 0. - ETA: 1s
# Epoch 133/200
# 69/69 [==============================] - 7s 102ms/step - loss: 1.0840 - val_loss: 4.5561 ETA: 4s - loss:  - ETA: 3s - - ETA: 0s - loss: 1
# Epoch 134/200
# 69/69 [==============================] - 7s 101ms/step - loss: 1.0401 - val_loss: 3.9440loss: 1.0 - ETA: 0s - loss:
# Epoch 135/200
# 69/69 [==============================] - 7s 103ms/step - loss: 1.0324 - val_loss: 2.1657
# Epoch 136/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.9189 - val_loss: 3.5682
# Epoch 137/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.8893 - val_loss: 2.9269- ETA: - ETA: 0s - loss: 0.
# Epoch 138/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.9461 - val_loss: 3.5173l - E - ETA: 1s - lo - ETA: 0s - loss: 0.9
# Epoch 139/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.9344 - val_loss: 4.0639: 5s - loss: 0 - ETA: 4s - l - ETA: 3s - loss - ETA: 2s - - ETA
# Epoch 140/200
# 69/69 [==============================] - 7s 102ms/step - loss: 1.1467 - val_loss: 3.9503- ETA: - ETA: 1s - l - ETA: 0s - loss
# Epoch 141/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.9375 - val_loss: 4.8881 ETA: 1s - loss: 0.91 - ETA: 1s - loss: 0.9 - ETA: 1s -
# Epoch 142/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8849 - val_loss: 4.4881
# Epoch 143/200
# 69/69 [==============================] - 7s 102ms/step - loss: 1.0388 - val_loss: 2.2407
# Epoch 144/200
# 69/69 [==============================] - 7s 102ms/step - loss: 1.0555 - val_loss: 3.0916
# Epoch 145/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.7883 - val_loss: 4.9029
# Epoch 146/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.2275 - val_loss: 5.9065
# Epoch 147/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.9829 - val_loss: 3.2208TA: 3s - lo
# Epoch 148/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8175 - val_loss: 1.4703
# Epoch 149/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0976 - val_loss: 1.5437
# Epoch 150/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8678 - val_loss: 4.4783
# Epoch 151/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.8894 - val_loss: 5.0908
# Epoch 152/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.6916 - val_loss: 4.3149
# Epoch 153/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8128 - val_loss: 0.8208
# Epoch 154/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.7822 - val_loss: 3.0050
# Epoch 155/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.7482 - val_loss: 0.7831
# Epoch 156/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.6397 - val_loss: 2.3348
# Epoch 157/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8198 - val_loss: 0.6065
# Epoch 158/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.7014 - val_loss: 3.8755
# Epoch 159/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.9173 - val_loss: 2.2873
# Epoch 160/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.5751 - val_loss: 1.6182
# Epoch 161/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9766 - val_loss: 5.0057 loss: 0
# Epoch 162/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.9579 - val_loss: 4.0307
# Epoch 163/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.8618 - val_loss: 4.0944
# Epoch 164/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.7006 - val_loss: 2.3193
# Epoch 165/200
# 69/69 [==============================] - 7s 98ms/step - loss: 0.6874 - val_loss: 3.7983
# Epoch 166/200
# 69/69 [==============================] - 7s 99ms/step - loss: 1.2549 - val_loss: 1.8850
# Epoch 167/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.6854 - val_loss: 3.4803
# Epoch 168/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8713 - val_loss: 5.5678
# Epoch 169/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.8960 - val_loss: 1.4349
# Epoch 170/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.8690 - val_loss: 1.7186s:  - ETA: 0s - loss: 0.87
# Epoch 171/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.6262 - val_loss: 3.0938ETA: 5s - loss
# Epoch 172/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9229 - val_loss: 1.2658
# Epoch 173/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.5636 - val_loss: 1.9839- l
# Epoch 174/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.7071 - val_loss: 1.4182
# Epoch 175/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.8068 - val_loss: 3.0475
# Epoch 176/200
# 69/69 [==============================] - 7s 105ms/step - loss: 0.8545 - val_loss: 2.0805
# Epoch 177/200
# 69/69 [==============================] - 7s 109ms/step - loss: 0.7782 - val_loss: 2.0019
# Epoch 178/200
# 69/69 [==============================] - 7s 109ms/step - loss: 0.8989 - val_loss: 2.5820: 3s - loss
# Epoch 179/200
# 69/69 [==============================] - 7s 107ms/step - loss: 1.0151 - val_loss: 4.4927
# Epoch 180/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.5228 - val_loss: 1.3893
# Epoch 181/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.6161 - val_loss: 4.5686
# Epoch 182/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9872 - val_loss: 5.7047
# Epoch 183/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0265 - val_loss: 3.2403
# Epoch 184/200
# 69/69 [==============================] - 7s 99ms/step - loss: 0.6992 - val_loss: 0.9743ss: 0.7 - ETA
# Epoch 185/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.6711 - val_loss: 1.7971
# Epoch 186/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.6242 - val_loss: 4.3874
# Epoch 187/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.7431 - val_loss: 2.5802
# Epoch 188/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.9280 - val_loss: 1.1034
# Epoch 189/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.7664 - val_loss: 11.7713
# Epoch 190/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.9861 - val_loss: 4.0572ETA: 0s - loss
# Epoch 191/200
# 69/69 [==============================] - 7s 101ms/step - loss: 1.1849 - val_loss: 4.0186
# Epoch 192/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0608 - val_loss: 4.8151
# Epoch 193/200
# 69/69 [==============================] - 7s 101ms/step - loss: 0.5636 - val_loss: 3.8053
# Epoch 194/200
# 69/69 [==============================] - 7s 100ms/step - loss: 1.0171 - val_loss: 0.9021
# Epoch 195/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8037 - val_loss: 1.5183
# Epoch 196/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.8442 - val_loss: 0.6621
# Epoch 197/200
# 69/69 [==============================] - 7s 100ms/step - loss: 0.7017 - val_loss: 1.6216
# Epoch 198/200
# 69/69 [==============================] - 7s 102ms/step - loss: 0.8088 - val_loss: 1.4202
# Epoch 199/200
# 69/69 [==============================] - 7s 104ms/step - loss: 0.7629 - val_loss: 0.6475
# Epoch 200/200
# 69/69 [==============================] - 7s 103ms/step - loss: 0.6264 - val_loss: 0.8192

# %%
Save_history = Model_history.history
Save_history = pd.DataFrame(Save_history)
writer = pd.ExcelWriter('C:/Users/Administrator/Desktop/surface/实验结果存放/PointNet-6000点版本_loss.xlsx')  #关键2，创建名称为hhh的excel表格
Save_history.to_excel(writer,'page_1',float_format='%.5f')  #关键3，float_format 控制精度，将data_df写到hhh表格的第一页中。若多个文件，可以在page_2中写入
writer.save()

# %%
############Test性能测试###################
def identification(predicted_gradient,real_gradient,threshold):
    AC13=[0,6,4,3.5,5.5,7.5,10.5,16,23.5,18.5,5,0]#级配
    AC16=[0,5.4,2.4,2.4,3.7,4.1,7.8,5.5,26.3,20.1,16.6,5.7]#级配 
    SMA13=[0,10.7,2.1,1.4,1.1,1.2,2.9,9.4,30.3,31.5,8.2,1.2]#级配
    UT5=[0,6.7,2,2.5,5,20,13.4,48.8,1.5,0.1,0,0]#级配
    OGFC10=[0,4,1.5,2,2,2.5,4,44,35,5,0,0]#级配
    
    R_AC13=np.average(np.abs(real_gradient-AC13))
    R_AC16=np.average(np.abs(real_gradient-AC16))
    R_SMA13=np.average(np.abs(real_gradient-SMA13))
    R_UT5=np.average(np.abs(real_gradient-UT5))
    R_OGFC10=np.average(np.abs(real_gradient-OGFC10))
    Real_result =np.argmin(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))
    """
    if np.average(np.abs(real_gradient-AC13))==0:
        Real_result=0
    elif np.average(np.abs(real_gradient-AC16))==0:
        Real_result=1
    elif np.average(np.abs(real_gradient-SMA13))==0:
        Real_result=2
    elif np.average(np.abs(real_gradient-UT5))==0:
        Real_result=3
    elif np.average(np.abs(real_gradient-OGFC10))==0:
        Real_result=4
    """
    R_AC13=np.average(np.abs(predicted_gradient-AC13))
    R_AC16=np.average(np.abs(predicted_gradient-AC16))
    R_SMA13=np.average(np.abs(predicted_gradient-SMA13))
    R_UT5=np.average(np.abs(predicted_gradient-UT5))
    R_OGFC10=np.average(np.abs(predicted_gradient-OGFC10))
    
    Predicted_result =np.argmin(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))
    
    if np.min(np.array([R_AC13,R_AC16,R_SMA13,R_UT5,R_OGFC10]))>threshold:
        Predicted_result = 5
    
    return Real_result, Predicted_result

n_classes = 12
PointNet= get_model(n_classes)
PointNet.load_weights("PointNet-6000点版本.h5")
PointNet.compile(optimizer=keras.optimizers.Adam(lr=1e-3), loss=tf.keras.losses.MAE)
PointNet.evaluate(Test_X_Data,Test_Y_Data)
Thr_list = [0.5,1,1.5,2,2.5,3]
for Thr in Thr_list:
    Real_result = []
    Predicted_result = []
    for i in range(len(Test_X_Data)):
        R,P=identification(PointNet(np.array(Test_X_Data[i])[np.newaxis,...])[0],Test_Y_Data[i],Thr)
        Real_result.append(R)
        Predicted_result.append(P)
    #######绘制混淆矩阵################
    C = confusion_matrix(Real_result, Predicted_result, labels=[0,1,2,3,4,5]) 
    plt.matshow(C, cmap=plt.cm.Reds) # 根据最下面的图按自己需求更改颜色
    plt.colorbar()
    for i in range(len(C)):
        for j in range(len(C)):
            plt.annotate(C[j, i], xy=(i, j), horizontalalignment='center', verticalalignment='center')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.xticks(range(0,6), labels=['AC13','AC16','SMA13','UT5','OGFC10','Other'], rotation=20) # 将x轴或y轴坐标，刻度 替换为文字/字符
    plt.yticks(range(0,6), labels=['AC13','AC16','SMA13','UT5','OGFC10','Other'])
    plt.savefig('C:/Users/Administrator/Desktop/surface/实验结果存放/PointNet-6000点版本'+ str(Thr) + '.png',dpi=600)#保存图片
    plt.show()
# Out:
# 7/7 [==============================] - 1s 46ms/step - loss: 0.4458
